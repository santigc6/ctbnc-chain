# %% [markdown]
# # First, let's generate a multi-label dataset for the CTBNC classifier

# %%
import os
import pandas as pd
import glob
import shutil
from sklearn.metrics import accuracy_score

# %% [markdown]
# # Let's use the default CTBNC
#
# https://github.com/dcodecasa/CTBNCToolkit

# %%
# !java -version
# Out:
# java version "1.8.0_241"
# Java(TM) SE Runtime Environment (build 1.8.0_241-b07)
# Java HotSpot(TM) 64-Bit Server VM (build 25.241-b07, mixed mode)

# %%
os.chdir('..')

# %%
# !dir
# Out:
#  El volumen de la unidad C no tiene etiqueta.
#  El número de serie del volumen es: 9CE1-B000
#
#  Directorio de C:\Users\berna\Downloads\MUIA\TFM\ctbnc-chain\CTBNCToolkit
#
# 06/04/2021  22:57    <DIR>          .
# 06/04/2021  22:57    <DIR>          ..
# 07/03/2021  20:15    <DIR>          .vscode
# 04/03/2021  01:10    <DIR>          CTBNCToolkit
# 06/04/2021  22:57           175.327 CTBNCToolkit.jar
# 07/04/2021  22:48    <DIR>          data
# 04/03/2021  01:10    <DIR>          lib
# 04/03/2021  01:10             1.518 LICENSE
# 04/03/2021  01:10             5.313 makefile
# 04/03/2021  01:10               124 MANIFEST.MF
# 07/04/2021  22:52    <DIR>          notebooks
# 04/03/2021  01:10             2.126 README.md
# 07/04/2021  20:14    <DIR>          results
#                5 archivos        184.408 bytes
#                8 dirs  421.659.295.744 bytes libres

# %% [markdown]
# # Define the parameters

# %%
inDir = os.path.join('data', 'rehab')
tmpDir = os.path.join('data', 'rehab-tmp')
outDir = os.path.join('results', 'extra')

# %%
features = ['S1','S2','S3','S4','S5','S6','S7','S8','S9','S10','S11','S12',
            'S13','S14','S15','S16','S17','S18','S19','S20','S21','S22','S23',
            'S24','S25','S26','S27','S28','S29']
time = 't'
labels = ['Exercise','ExerciseMode']

# %% [markdown]
# # Let's make predictions for each one of the labels independently

# %%
features_cmd = ','.join(f"{item}" for item in features)
features_cmd
# Out:
# 'S1,S2,S3,S4,S5,S6,S7,S8,S9,S10,S11,S12,S13,S14,S15,S16,S17,S18,S19,S20,S21,S22,S23,S24,S25,S26,S27,S28,S29'

# %%
# Train and test separate directories to learn the model.

# !java -jar CTBNCToolkit.jar --v --CTBNC=CTNB --validation=HO,0.75 --validColumns=S1,S2,S3,S4,S5,S6,S7,S8,S9,S10,S11,S12,S13,S14,S15,S16,S17,S18,S19,S20,S21,S22,S23,S24,S25,S26,S27,S28,S29,Exercise --timeName=t --className=ExerciseMode --training=data/rehab-split/train --rPath=results/extra data/rehab-split/test

# %%
# --rPath = {outDir}
for item in labels:
    # !java -jar CTBNCToolkit.jar --v --CTBNC=CTNB --validation=HO,0.75 --validColumns={features_cmd} --timeName={time} --className={item} --rPath=results/{item} {inDir}
# Out:
# Datasets generation:
#
# 	. single dataset loading
#
# 	. dataset permutation
#
# 	. dataset dimension cutting (% = 1.0)
#
# Datasets generation (END)
#
# Learning algorithms generation:
#
# 	. model 0: CTNB
#
# 		. Mxx_prior = 1.0
#
# 		. Tx_prior = 0.005
#
# 		. Px_prior = 1.0
#
# 		. generation of classification parameter learning algorithm
#
# Learning algorithms generation (END)
#
# Inference algorithm generation:
#
# 	. probabilities = true
#
# 	. binary class decider = disabled
#
# 	. classification algorithm
#
# Inference algorithm generation (END)
#
# Hold out
#
# Test factories generation:
#
# 	. model CTNB
#
# Test factories generation (END)
#
# Execute tests:
#
# 	. model M0_CTNB
#
# 	. test running
#
#
#
# Hold out schema (cut = 0.75)
# Training set uses the first 630 trajectories
# Test set uses the last 209 trajectories
#
# Learning (training set of 630 trajectories):
# Model learnt in 0.581 seconds
#
# Testing (test set of 210trajectories):
# Inference on 2_3_4_5.csv test set trajectory
# 2_3_4_5.csv: True Class: 3, Predicted: 3, Probability: 1.0, Inference time: 0.042
# Inference on 4_6_3_4.csv test set trajectory
# 4_6_3_4.csv: True Class: 6, Predicted: 6, Probability: 1.0, Inference time: 0.006
# Inference on 3_7_6_5.csv test set trajectory
# 3_7_6_5.csv: True Class: 7, Predicted: 7, Probability: 1.0, Inference time: 0.005
# Inference on 3_7_2_3.csv test set trajectory
# 3_7_2_3.csv: True Class: 7, Predicted: 7, Probability: 1.0, Inference time: 0.004
# Inference on 4_5_5_5.csv test set trajectory
# 4_5_5_5.csv: True Class: 5, Predicted: 5, Probability: 1.0, Inference time: 0.002
# Inference on 1_7_1_5.csv test set trajectory
# 1_7_1_5.csv: True Class: 7, Predicted: 7, Probability: 1.0, Inference time: 0.008
# Inference on 3_2_2_3.csv test set trajectory
# 3_2_2_3.csv: True Class: 2, Predicted: 2, Probability: 1.0, Inference time: 0.003
# Inference on 1_6_3_4.csv test set trajectory
# 1_6_3_4.csv: True Class: 6, Predicted: 6, Probability: 1.0, Inference time: 0.002
# Inference on 2_2_2_4.csv test set trajectory
# 2_2_2_4.csv: True Class: 2, Predicted: 2, Probability: 1.0, Inference time: 0.006
# Inference on 2_3_3_4.csv test set trajectory
# 2_3_3_4.csv: True Class: 3, Predicted: 3, Probability: 1.0, Inference time: 0.003
# Inference on 1_1_2_1.csv test set trajectory
# 1_1_2_1.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.004
# Inference on 4_6_2_2.csv test set trajectory
# 4_6_2_2.csv: True Class: 6, Predicted: 6, Probability: 1.0, Inference time: 0.003
# Inference on 4_7_2_2.csv test set trajectory
# 4_7_2_2.csv: True Class: 7, Predicted: 7, Probability: 1.0, Inference time: 0.003
# Inference on 1_5_6_1.csv test set trajectory
# 1_5_6_1.csv: True Class: 5, Predicted: 5, Probability: 1.0, Inference time: 0.004
# Inference on 1_7_1_1.csv test set trajectory
# 1_7_1_1.csv: True Class: 7, Predicted: 7, Probability: 1.0, Inference time: 0.007
# Inference on 4_5_4_1.csv test set trajectory
# 4_5_4_1.csv: True Class: 5, Predicted: 5, Probability: 1.0, Inference time: 0.002
# Inference on 4_1_5_3.csv test set trajectory
# 4_1_5_3.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.007
# Inference on 3_5_4_5.csv test set trajectory
# 3_5_4_5.csv: True Class: 5, Predicted: 5, Probability: 0.9999999999999999, Inference time: 0.003
# Inference on 2_3_2_5.csv test set trajectory
# 2_3_2_5.csv: True Class: 3, Predicted: 3, Probability: 1.0, Inference time: 0.004
# Inference on 4_2_1_2.csv test set trajectory
# 4_2_1_2.csv: True Class: 2, Predicted: 2, Probability: 1.0, Inference time: 0.007
# Inference on 3_1_4_3.csv test set trajectory
# 3_1_4_3.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.004
# Inference on 2_1_2_2.csv test set trajectory
# 2_1_2_2.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.005
# Inference on 1_6_3_2.csv test set trajectory
# 1_6_3_2.csv: True Class: 6, Predicted: 6, Probability: 1.0, Inference time: 0.002
# Inference on 4_6_4_3.csv test set trajectory
# 4_6_4_3.csv: True Class: 6, Predicted: 6, Probability: 1.0, Inference time: 0.005
# Inference on 4_1_5_2.csv test set trajectory
# 4_1_5_2.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.004
# Inference on 4_3_2_2.csv test set trajectory
# 4_3_2_2.csv: True Class: 3, Predicted: 3, Probability: 1.0, Inference time: 0.004
# Inference on 4_5_6_5.csv test set trajectory
# 4_5_6_5.csv: True Class: 5, Predicted: 5, Probability: 1.0, Inference time: 0.004
# Inference on 3_2_3_5.csv test set trajectory
# 3_2_3_5.csv: True Class: 2, Predicted: 2, Probability: 1.0, Inference time: 0.004
# Inference on 4_1_5_1.csv test set trajectory
# Error: NaN probability value
# Inference on 3_6_6_3.csv test set trajectory
# 3_6_6_3.csv: True Class: 6, Predicted: 6, Probability: 1.0, Inference time: 0.005
# Inference on 1_1_1_2.csv test set trajectory
# 1_1_1_2.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.008
# Inference on 2_2_6_4.csv test set trajectory
# 2_2_6_4.csv: True Class: 2, Predicted: 2, Probability: 1.0, Inference time: 0.004
# Inference on 3_4_3_3.csv test set trajectory
# 3_4_3_3.csv: True Class: 4, Predicted: 4, Probability: 1.0, Inference time: 0.002
# Inference on 4_5_1_2.csv test set trajectory
# 4_5_1_2.csv: True Class: 5, Predicted: 5, Probability: 1.0, Inference time: 0.007
# Inference on 2_4_3_3.csv test set trajectory
# 2_4_3_3.csv: True Class: 4, Predicted: 4, Probability: 1.0, Inference time: 0.002
# Inference on 1_1_1_3.csv test set trajectory
# 1_1_1_3.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.008
# Inference on 4_7_1_4.csv test set trajectory
# 4_7_1_4.csv: True Class: 7, Predicted: 7, Probability: 1.0, Inference time: 0.005
# Inference on 4_3_5_4.csv test set trajectory
# 4_3_5_4.csv: True Class: 3, Predicted: 3, Probability: 1.0, Inference time: 0.004
# Inference on 3_2_5_1.csv test set trajectory
# 3_2_5_1.csv: True Class: 2, Predicted: 2, Probability: 1.0, Inference time: 0.004
# Inference on 2_2_1_5.csv test set trajectory
# 2_2_1_5.csv: True Class: 2, Predicted: 2, Probability: 1.0, Inference time: 0.007
# Inference on 3_3_2_3.csv test set trajectory
# 3_3_2_3.csv: True Class: 3, Predicted: 3, Probability: 1.0, Inference time: 0.004
# Inference on 4_7_2_3.csv test set trajectory
# 4_7_2_3.csv: True Class: 7, Predicted: 7, Probability: 1.0, Inference time: 0.004
# Inference on 2_7_5_2.csv test set trajectory
# 2_7_5_2.csv: True Class: 7, Predicted: 7, Probability: 1.0, Inference time: 0.004
# Inference on 1_5_6_2.csv test set trajectory
# 1_5_6_2.csv: True Class: 5, Predicted: 5, Probability: 1.0, Inference time: 0.003
# Inference on 1_2_1_2.csv test set trajectory
# 1_2_1_2.csv: True Class: 2, Predicted: 2, Probability: 1.0, Inference time: 0.009
# Inference on 4_3_5_2.csv test set trajectory
# 4_3_5_2.csv: True Class: 3, Predicted: 3, Probability: 1.0, Inference time: 0.003
# Inference on 3_3_5_3.csv test set trajectory
# 3_3_5_3.csv: True Class: 3, Predicted: 3, Probability: 1.0, Inference time: 0.003
# Inference on 4_4_4_3.csv test set trajectory
# 4_4_4_3.csv: True Class: 4, Predicted: 4, Probability: 1.0, Inference time: 0.002
# Inference on 4_3_6_2.csv test set trajectory
# 4_3_6_2.csv: True Class: 3, Predicted: 3, Probability: 1.0, Inference time: 0.004
# Inference on 2_5_6_2.csv test set trajectory
# 2_5_6_2.csv: True Class: 5, Predicted: 5, Probability: 1.0, Inference time: 0.003
# Inference on 3_6_2_2.csv test set trajectory
# 3_6_2_2.csv: True Class: 6, Predicted: 6, Probability: 1.0, Inference time: 0.004
# Inference on 3_1_4_2.csv test set trajectory
# 3_1_4_2.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.003
# Inference on 4_3_3_2.csv test set trajectory
# 4_3_3_2.csv: True Class: 3, Predicted: 3, Probability: 1.0, Inference time: 0.003
# Inference on 2_1_6_5.csv test set trajectory
# 2_1_6_5.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.004
# Inference on 1_6_5_3.csv test set trajectory
# 1_6_5_3.csv: True Class: 6, Predicted: 6, Probability: 1.0, Inference time: 0.005
# Inference on 1_3_5_5.csv test set trajectory
# 1_3_5_5.csv: True Class: 3, Predicted: 3, Probability: 1.0, Inference time: 0.004
# Inference on 2_1_5_3.csv test set trajectory
# 2_1_5_3.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.005
# Inference on 4_5_6_4.csv test set trajectory
# 4_5_6_4.csv: True Class: 5, Predicted: 5, Probability: 1.0, Inference time: 0.004
# Inference on 3_2_5_3.csv test set trajectory
# 3_2_5_3.csv: True Class: 2, Predicted: 2, Probability: 1.0, Inference time: 0.004
# Inference on 2_5_1_1.csv test set trajectory
# 2_5_1_1.csv: True Class: 5, Predicted: 5, Probability: 1.0, Inference time: 0.005
# Inference on 2_6_1_1.csv test set trajectory
# 2_6_1_1.csv: True Class: 6, Predicted: 7, Probability: 1.0, Inference time: 0.007
# Inference on 2_7_5_1.csv test set trajectory
# 2_7_5_1.csv: True Class: 7, Predicted: 7, Probability: 1.0, Inference time: 0.003
# Inference on 1_6_5_2.csv test set trajectory
# 1_6_5_2.csv: True Class: 6, Predicted: 6, Probability: 1.0, Inference time: 0.004
# Inference on 1_2_3_2.csv test set trajectory
# 1_2_3_2.csv: True Class: 2, Predicted: 2, Probability: 1.0, Inference time: 0.003
# Inference on 3_5_6_4.csv test set trajectory
# 3_5_6_4.csv: True Class: 5, Predicted: 5, Probability: 1.0, Inference time: 0.006
# Inference on 3_5_6_1.csv test set trajectory
# 3_5_6_1.csv: True Class: 5, Predicted: 5, Probability: 1.0, Inference time: 0.004
# Inference on 1_2_4_1.csv test set trajectory
# 1_2_4_1.csv: True Class: 2, Predicted: 2, Probability: 1.0, Inference time: 0.003
# Inference on 1_1_6_4.csv test set trajectory
# 1_1_6_4.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.003
# Inference on 1_3_6_3.csv test set trajectory
# 1_3_6_3.csv: True Class: 3, Predicted: 3, Probability: 1.0, Inference time: 0.002
# Inference on 4_7_5_5.csv test set trajectory
# 4_7_5_5.csv: True Class: 7, Predicted: 7, Probability: 1.0, Inference time: 0.004
# Inference on 2_6_5_3.csv test set trajectory
# 2_6_5_3.csv: True Class: 6, Predicted: 6, Probability: 1.0, Inference time: 0.002
# Inference on 4_5_4_3.csv test set trajectory
# 4_5_4_3.csv: True Class: 5, Predicted: 5, Probability: 1.0, Inference time: 0.003
# Inference on 4_2_6_5.csv test set trajectory
# 4_2_6_5.csv: True Class: 2, Predicted: 2, Probability: 1.0, Inference time: 0.002
# Inference on 2_3_6_1.csv test set trajectory
# 2_3_6_1.csv: True Class: 3, Predicted: 3, Probability: 1.0, Inference time: 0.003
# Inference on 1_3_6_1.csv test set trajectory
# 1_3_6_1.csv: True Class: 3, Predicted: 5, Probability: 1.0, Inference time: 0.003
# Inference on 1_7_4_3.csv test set trajectory
# 1_7_4_3.csv: True Class: 7, Predicted: 7, Probability: 1.0, Inference time: 0.003
# Inference on 3_1_5_4.csv test set trajectory
# 3_1_5_4.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.003
# Inference on 3_7_5_1.csv test set trajectory
# 3_7_5_1.csv: True Class: 7, Predicted: 7, Probability: 1.0, Inference time: 0.003
# Inference on 2_3_6_2.csv test set trajectory
# 2_3_6_2.csv: True Class: 3, Predicted: 3, Probability: 1.0, Inference time: 0.002
# Inference on 1_7_1_4.csv test set trajectory
# 1_7_1_4.csv: True Class: 7, Predicted: 7, Probability: 1.0, Inference time: 0.005
# Inference on 2_4_5_5.csv test set trajectory
# 2_4_5_5.csv: True Class: 4, Predicted: 4, Probability: 1.0, Inference time: 0.003
# Inference on 4_7_1_1.csv test set trajectory
# 4_7_1_1.csv: True Class: 7, Predicted: 7, Probability: 1.0, Inference time: 0.005
# Inference on 1_4_2_3.csv test set trajectory
# 1_4_2_3.csv: True Class: 4, Predicted: 4, Probability: 1.0, Inference time: 0.003
# Inference on 3_5_2_4.csv test set trajectory
# 3_5_2_4.csv: True Class: 5, Predicted: 5, Probability: 1.0, Inference time: 0.002
# Inference on 1_1_2_3.csv test set trajectory
# 1_1_2_3.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.004
# Inference on 2_5_5_1.csv test set trajectory
# 2_5_5_1.csv: True Class: 5, Predicted: 5, Probability: 1.0, Inference time: 0.003
# Inference on 4_4_5_4.csv test set trajectory
# 4_4_5_4.csv: True Class: 4, Predicted: 4, Probability: 1.0, Inference time: 0.002
# Inference on 2_3_1_3.csv test set trajectory
# 2_3_1_3.csv: True Class: 3, Predicted: 3, Probability: 1.0, Inference time: 0.004
# Inference on 3_6_5_4.csv test set trajectory
# 3_6_5_4.csv: True Class: 6, Predicted: 6, Probability: 1.0, Inference time: 0.002
# Inference on 3_1_1_5.csv test set trajectory
# 3_1_1_5.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.007
# Inference on 4_7_4_4.csv test set trajectory
# 4_7_4_4.csv: True Class: 7, Predicted: 7, Probability: 1.0, Inference time: 0.003
# Inference on 4_5_6_2.csv test set trajectory
# 4_5_6_2.csv: True Class: 5, Predicted: 5, Probability: 1.0, Inference time: 0.003
# Inference on 4_6_2_3.csv test set trajectory
# 4_6_2_3.csv: True Class: 6, Predicted: 6, Probability: 1.0, Inference time: 0.003
# Inference on 3_3_4_2.csv test set trajectory
# 3_3_4_2.csv: True Class: 3, Predicted: 3, Probability: 1.0, Inference time: 0.003
# Inference on 4_2_5_3.csv test set trajectory
# 4_2_5_3.csv: True Class: 2, Predicted: 2, Probability: 1.0, Inference time: 0.002
# Inference on 3_3_1_3.csv test set trajectory
# 3_3_1_3.csv: True Class: 3, Predicted: 3, Probability: 1.0, Inference time: 0.004
# Inference on 4_4_6_1.csv test set trajectory
# 4_4_6_1.csv: True Class: 4, Predicted: 4, Probability: 1.0, Inference time: 0.002
# Inference on 1_4_4_5.csv test set trajectory
# 1_4_4_5.csv: True Class: 4, Predicted: 4, Probability: 1.0, Inference time: 0.007
# Inference on 3_3_6_4.csv test set trajectory
# 3_3_6_4.csv: True Class: 3, Predicted: 3, Probability: 1.0, Inference time: 0.003
# Inference on 1_4_5_1.csv test set trajectory
# 1_4_5_1.csv: True Class: 4, Predicted: 4, Probability: 1.0, Inference time: 0.003
# Inference on 2_3_6_5.csv test set trajectory
# 2_3_6_5.csv: True Class: 3, Predicted: 3, Probability: 1.0, Inference time: 0.003
# Inference on 3_6_3_1.csv test set trajectory
# 3_6_3_1.csv: True Class: 6, Predicted: 6, Probability: 1.0, Inference time: 0.002
# Inference on 3_7_2_5.csv test set trajectory
# 3_7_2_5.csv: True Class: 7, Predicted: 7, Probability: 1.0, Inference time: 0.003
# Inference on 2_1_6_4.csv test set trajectory
# 2_1_6_4.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.004
# Inference on 2_7_5_4.csv test set trajectory
# 2_7_5_4.csv: True Class: 7, Predicted: 7, Probability: 1.0, Inference time: 0.003
# Inference on 3_4_3_4.csv test set trajectory
# 3_4_3_4.csv: True Class: 4, Predicted: 4, Probability: 1.0, Inference time: 0.002
# Inference on 3_1_5_1.csv test set trajectory
# 3_1_5_1.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.002
# Inference on 3_3_3_4.csv test set trajectory
# 3_3_3_4.csv: True Class: 3, Predicted: 3, Probability: 1.0, Inference time: 0.003
# Inference on 4_7_6_2.csv test set trajectory
# 4_7_6_2.csv: True Class: 7, Predicted: 7, Probability: 1.0, Inference time: 0.003
# Inference on 1_4_6_1.csv test set trajectory
# 1_4_6_1.csv: True Class: 4, Predicted: 4, Probability: 1.0, Inference time: 0.002
# Inference on 3_1_2_5.csv test set trajectory
# 3_1_2_5.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.004
# Inference on 2_6_3_1.csv test set trajectory
# 2_6_3_1.csv: True Class: 6, Predicted: 6, Probability: 1.0, Inference time: 0.001
# Inference on 4_5_2_3.csv test set trajectory
# 4_5_2_3.csv: True Class: 5, Predicted: 5, Probability: 1.0, Inference time: 0.002
# Inference on 4_3_1_3.csv test set trajectory
# 4_3_1_3.csv: True Class: 3, Predicted: 3, Probability: 1.0, Inference time: 0.004
# Inference on 4_7_3_4.csv test set trajectory
# 4_7_3_4.csv: True Class: 7, Predicted: 7, Probability: 1.0, Inference time: 0.002
# Inference on 1_4_2_2.csv test set trajectory
# 1_4_2_2.csv: True Class: 4, Predicted: 4, Probability: 1.0, Inference time: 0.002
# Inference on 4_4_4_4.csv test set trajectory
# 4_4_4_4.csv: True Class: 4, Predicted: 4, Probability: 1.0, Inference time: 0.003
# Inference on 4_6_1_2.csv test set trajectory
# 4_6_1_2.csv: True Class: 6, Predicted: 6, Probability: 1.0, Inference time: 0.004
# Inference on 4_7_1_5.csv test set trajectory
# 4_7_1_5.csv: True Class: 7, Predicted: 7, Probability: 1.0, Inference time: 0.004
# Inference on 4_6_4_5.csv test set trajectory
# 4_6_4_5.csv: True Class: 6, Predicted: 6, Probability: 1.0, Inference time: 0.004
# Inference on 2_5_4_5.csv test set trajectory
# 2_5_4_5.csv: True Class: 5, Predicted: 5, Probability: 1.0, Inference time: 0.002
# Inference on 2_7_4_3.csv test set trajectory
# 2_7_4_3.csv: True Class: 7, Predicted: 7, Probability: 1.0, Inference time: 0.004
# Inference on 4_7_5_3.csv test set trajectory
# 4_7_5_3.csv: True Class: 7, Predicted: 7, Probability: 1.0, Inference time: 0.004
# Inference on 1_4_3_3.csv test set trajectory
# 1_4_3_3.csv: True Class: 4, Predicted: 4, Probability: 1.0, Inference time: 0.002
# Inference on 3_4_1_5.csv test set trajectory
# 3_4_1_5.csv: True Class: 4, Predicted: 4, Probability: 1.0, Inference time: 0.007
# Inference on 4_2_4_5.csv test set trajectory
# 4_2_4_5.csv: True Class: 2, Predicted: 2, Probability: 1.0, Inference time: 0.002
# Inference on 2_7_1_4.csv test set trajectory
# 2_7_1_4.csv: True Class: 7, Predicted: 7, Probability: 1.0, Inference time: 0.006
# Inference on 1_3_1_5.csv test set trajectory
# 1_3_1_5.csv: True Class: 3, Predicted: 3, Probability: 1.0, Inference time: 0.005
# Inference on 1_7_5_2.csv test set trajectory
# 1_7_5_2.csv: True Class: 7, Predicted: 7, Probability: 1.0, Inference time: 0.003
# Inference on 3_6_3_5.csv test set trajectory
# 3_6_3_5.csv: True Class: 6, Predicted: 6, Probability: 1.0, Inference time: 0.002
# Inference on 4_3_3_5.csv test set trajectory
# 4_3_3_5.csv: True Class: 3, Predicted: 3, Probability: 1.0, Inference time: 0.002
# Inference on 3_1_3_2.csv test set trajectory
# 3_1_3_2.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.002
# Inference on 4_1_4_1.csv test set trajectory
# 4_1_4_1.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.003
# Inference on 4_3_4_5.csv test set trajectory
# 4_3_4_5.csv: True Class: 3, Predicted: 3, Probability: 1.0, Inference time: 0.002
# Inference on 2_5_3_1.csv test set trajectory
# 2_5_3_1.csv: True Class: 5, Predicted: 5, Probability: 1.0, Inference time: 0.002
# Inference on 4_4_6_2.csv test set trajectory
# 4_4_6_2.csv: True Class: 4, Predicted: 4, Probability: 1.0, Inference time: 0.002
# Inference on 2_7_6_2.csv test set trajectory
# 2_7_6_2.csv: True Class: 7, Predicted: 7, Probability: 1.0, Inference time: 0.003
# Inference on 4_3_1_5.csv test set trajectory
# 4_3_1_5.csv: True Class: 3, Predicted: 3, Probability: 1.0, Inference time: 0.005
# Inference on 2_4_6_2.csv test set trajectory
# 2_4_6_2.csv: True Class: 4, Predicted: 4, Probability: 1.0, Inference time: 0.003
# Inference on 4_6_1_4.csv test set trajectory
# 4_6_1_4.csv: True Class: 6, Predicted: 6, Probability: 1.0, Inference time: 0.003
# Inference on 2_6_1_5.csv test set trajectory
# 2_6_1_5.csv: True Class: 6, Predicted: 6, Probability: 1.0, Inference time: 0.004
# Inference on 1_5_3_5.csv test set trajectory
# 1_5_3_5.csv: True Class: 5, Predicted: 5, Probability: 1.0, Inference time: 0.001
# Inference on 2_7_1_3.csv test set trajectory
# 2_7_1_3.csv: True Class: 7, Predicted: 7, Probability: 1.0, Inference time: 0.005
# Inference on 3_1_2_1.csv test set trajectory
# 3_1_2_1.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.003
# Inference on 1_1_1_4.csv test set trajectory
# 1_1_1_4.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.005
# Inference on 3_2_2_2.csv test set trajectory
# 3_2_2_2.csv: True Class: 2, Predicted: 2, Probability: 1.0, Inference time: 0.003
# Inference on 3_5_1_1.csv test set trajectory
# 3_5_1_1.csv: True Class: 5, Predicted: 5, Probability: 1.0, Inference time: 0.005
# Inference on 2_7_5_5.csv test set trajectory
# 2_7_5_5.csv: True Class: 7, Predicted: 7, Probability: 1.0, Inference time: 0.002
# Inference on 4_5_1_5.csv test set trajectory
# 4_5_1_5.csv: True Class: 5, Predicted: 5, Probability: 1.0, Inference time: 0.004
# Inference on 1_5_4_2.csv test set trajectory
# 1_5_4_2.csv: True Class: 5, Predicted: 5, Probability: 1.0, Inference time: 0.003
# Inference on 1_2_6_1.csv test set trajectory
# 1_2_6_1.csv: True Class: 2, Predicted: 2, Probability: 1.0, Inference time: 0.003
# Inference on 1_5_3_4.csv test set trajectory
# 1_5_3_4.csv: True Class: 5, Predicted: 5, Probability: 1.0, Inference time: 0.003
# Inference on 4_5_6_1.csv test set trajectory
# 4_5_6_1.csv: True Class: 5, Predicted: 5, Probability: 1.0, Inference time: 0.002
# Inference on 1_3_5_3.csv test set trajectory
# 1_3_5_3.csv: True Class: 3, Predicted: 3, Probability: 1.0, Inference time: 0.002
# Inference on 4_3_2_1.csv test set trajectory
# 4_3_2_1.csv: True Class: 3, Predicted: 3, Probability: 1.0, Inference time: 0.003
# Inference on 1_3_6_2.csv test set trajectory
# 1_3_6_2.csv: True Class: 3, Predicted: 2, Probability: 1.0, Inference time: 0.003
# Inference on 4_4_1_5.csv test set trajectory
# 4_4_1_5.csv: True Class: 4, Predicted: 4, Probability: 1.0, Inference time: 0.006
# Inference on 4_4_2_2.csv test set trajectory
# 4_4_2_2.csv: True Class: 4, Predicted: 4, Probability: 1.0, Inference time: 0.003
# Inference on 3_6_6_1.csv test set trajectory
# Error: NaN probability value
# Inference on 4_6_1_1.csv test set trajectory
# 4_6_1_1.csv: True Class: 6, Predicted: 6, Probability: 1.0, Inference time: 0.008
# Inference on 3_1_3_4.csv test set trajectory
# 3_1_3_4.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.003
# Inference on 2_4_3_5.csv test set trajectory
# 2_4_3_5.csv: True Class: 4, Predicted: 4, Probability: 1.0, Inference time: 0.003
# Inference on 2_6_6_4.csv test set trajectory
# 2_6_6_4.csv: True Class: 6, Predicted: 7, Probability: 1.0, Inference time: 0.005
# Inference on 4_4_6_3.csv test set trajectory
# 4_4_6_3.csv: True Class: 4, Predicted: 4, Probability: 1.0, Inference time: 0.004
# Inference on 3_3_4_4.csv test set trajectory
# 3_3_4_4.csv: True Class: 3, Predicted: 3, Probability: 1.0, Inference time: 0.002
# Inference on 1_2_3_3.csv test set trajectory
# 1_2_3_3.csv: True Class: 2, Predicted: 2, Probability: 1.0, Inference time: 0.003
# Inference on 4_4_3_3.csv test set trajectory
# 4_4_3_3.csv: True Class: 4, Predicted: 4, Probability: 1.0, Inference time: 0.003
# Inference on 2_6_6_1.csv test set trajectory
# 2_6_6_1.csv: True Class: 6, Predicted: 6, Probability: 1.0, Inference time: 0.004
# Inference on 4_7_3_3.csv test set trajectory
# 4_7_3_3.csv: True Class: 7, Predicted: 7, Probability: 1.0, Inference time: 0.003
# Inference on 3_7_6_3.csv test set trajectory
# 3_7_6_3.csv: True Class: 7, Predicted: 7, Probability: 1.0, Inference time: 0.004
# Inference on 1_7_2_1.csv test set trajectory
# 1_7_2_1.csv: True Class: 7, Predicted: 7, Probability: 1.0, Inference time: 0.005
# Inference on 4_3_4_1.csv test set trajectory
# 4_3_4_1.csv: True Class: 3, Predicted: 3, Probability: 1.0, Inference time: 0.002
# Inference on 1_7_4_1.csv test set trajectory
# 1_7_4_1.csv: True Class: 7, Predicted: 7, Probability: 1.0, Inference time: 0.004
# Inference on 2_1_4_4.csv test set trajectory
# 2_1_4_4.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.005
# Inference on 3_7_2_1.csv test set trajectory
# 3_7_2_1.csv: True Class: 7, Predicted: 7, Probability: 1.0, Inference time: 0.004
# Inference on 3_5_2_3.csv test set trajectory
# 3_5_2_3.csv: True Class: 5, Predicted: 5, Probability: 1.0, Inference time: 0.004
# Inference on 3_3_6_1.csv test set trajectory
# 3_3_6_1.csv: True Class: 3, Predicted: 5, Probability: 1.0, Inference time: 0.005
# Inference on 4_7_1_3.csv test set trajectory
# 4_7_1_3.csv: True Class: 7, Predicted: 7, Probability: 1.0, Inference time: 0.007
# Inference on 2_1_3_5.csv test set trajectory
# 2_1_3_5.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.003
# Inference on 4_4_2_3.csv test set trajectory
# 4_4_2_3.csv: True Class: 4, Predicted: 4, Probability: 1.0, Inference time: 0.004
# Inference on 2_3_5_4.csv test set trajectory
# 2_3_5_4.csv: True Class: 3, Predicted: 3, Probability: 1.0, Inference time: 0.004
# Inference on 1_2_6_4.csv test set trajectory
# 1_2_6_4.csv: True Class: 2, Predicted: 2, Probability: 1.0, Inference time: 0.004
# Inference on 3_3_1_2.csv test set trajectory
# 3_3_1_2.csv: True Class: 3, Predicted: 3, Probability: 1.0, Inference time: 0.009
# Inference on 2_6_1_4.csv test set trajectory
# 2_6_1_4.csv: True Class: 6, Predicted: 6, Probability: 1.0, Inference time: 0.008
# Inference on 3_3_2_1.csv test set trajectory
# 3_3_2_1.csv: True Class: 3, Predicted: 3, Probability: 1.0, Inference time: 0.003
# Inference on 1_7_2_2.csv test set trajectory
# 1_7_2_2.csv: True Class: 7, Predicted: 7, Probability: 1.0, Inference time: 0.003
# Inference on 4_2_6_4.csv test set trajectory
# 4_2_6_4.csv: True Class: 2, Predicted: 2, Probability: 1.0, Inference time: 0.003
# Inference on 2_1_5_1.csv test set trajectory
# 2_1_5_1.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.003
# Inference on 1_5_4_3.csv test set trajectory
# 1_5_4_3.csv: True Class: 5, Predicted: 5, Probability: 1.0, Inference time: 0.003
# Inference on 2_4_6_5.csv test set trajectory
# 2_4_6_5.csv: True Class: 4, Predicted: 4, Probability: 1.0, Inference time: 0.004
# Inference on 4_7_3_2.csv test set trajectory
# 4_7_3_2.csv: True Class: 7, Predicted: 7, Probability: 1.0, Inference time: 0.002
# Inference on 3_1_5_2.csv test set trajectory
# 3_1_5_2.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.004
# Inference on 3_7_2_4.csv test set trajectory
# 3_7_2_4.csv: True Class: 7, Predicted: 7, Probability: 1.0, Inference time: 0.003
# Inference on 4_3_1_2.csv test set trajectory
# 4_3_1_2.csv: True Class: 3, Predicted: 3, Probability: 1.0, Inference time: 0.004
# Inference on 1_3_2_3.csv test set trajectory
# 1_3_2_3.csv: True Class: 3, Predicted: 3, Probability: 1.0, Inference time: 0.003
# Inference on 3_6_4_3.csv test set trajectory
# 3_6_4_3.csv: True Class: 6, Predicted: 6, Probability: 1.0, Inference time: 0.004
# Inference on 2_1_4_2.csv test set trajectory
# 2_1_4_2.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.003
# Inference on 2_4_6_4.csv test set trajectory
# 2_4_6_4.csv: True Class: 4, Predicted: 4, Probability: 1.0, Inference time: 0.003
# Inference on 1_4_3_4.csv test set trajectory
# 1_4_3_4.csv: True Class: 4, Predicted: 4, Probability: 1.0, Inference time: 0.002
# Inference on 1_2_3_4.csv test set trajectory
# 1_2_3_4.csv: True Class: 2, Predicted: 2, Probability: 1.0, Inference time: 0.002
# Inference on 4_2_3_2.csv test set trajectory
# 4_2_3_2.csv: True Class: 2, Predicted: 2, Probability: 1.0, Inference time: 0.002
# Inference on 3_4_4_5.csv test set trajectory
# 3_4_4_5.csv: True Class: 4, Predicted: 4, Probability: 1.0, Inference time: 0.002
# Inference on 2_3_4_4.csv test set trajectory
# 2_3_4_4.csv: True Class: 3, Predicted: 3, Probability: 1.0, Inference time: 0.002
# Inference on 2_1_3_4.csv test set trajectory
# 2_1_3_4.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.003
# Inference on 2_3_5_3.csv test set trajectory
# 2_3_5_3.csv: True Class: 3, Predicted: 3, Probability: 1.0, Inference time: 0.002
# Inference on 2_5_4_1.csv test set trajectory
# 2_5_4_1.csv: True Class: 5, Predicted: 5, Probability: 1.0, Inference time: 0.003
# Inference on 2_5_2_5.csv test set trajectory
# 2_5_2_5.csv: True Class: 5, Predicted: 5, Probability: 1.0, Inference time: 0.003
# Inference on 2_3_6_4.csv test set trajectory
# 2_3_6_4.csv: True Class: 3, Predicted: 3, Probability: 1.0, Inference time: 0.003
# Inference on 3_4_2_3.csv test set trajectory
# 3_4_2_3.csv: True Class: 4, Predicted: 4, Probability: 1.0, Inference time: 0.003
# Inference on 3_2_1_1.csv test set trajectory
# 3_2_1_1.csv: True Class: 2, Predicted: 2, Probability: 1.0, Inference time: 0.005
# 	. result printing
#
# M0_CTNB results printing
# Execute tests (END)
#
# Comparison tests:
#
# Comparison tests (END)
# Datasets generation:
#
# 	. single dataset loading
#
# 	. dataset permutation
#
# 	. dataset dimension cutting (% = 1.0)
#
# Datasets generation (END)
#
# Learning algorithms generation:
#
# 	. model 0: CTNB
#
# 		. Mxx_prior = 1.0
#
# 		. Tx_prior = 0.005
#
# 		. Px_prior = 1.0
#
# 		. generation of classification parameter learning algorithm
#
# Learning algorithms generation (END)
#
# Inference algorithm generation:
#
# 	. probabilities = true
#
# 	. binary class decider = disabled
#
# 	. classification algorithm
#
# Inference algorithm generation (END)
#
# Hold out
#
# Test factories generation:
#
# 	. model CTNB
#
# Test factories generation (END)
#
# Execute tests:
#
# 	. model M0_CTNB
#
# 	. test running
#
#
#
# Hold out schema (cut = 0.75)
# Training set uses the first 630 trajectories
# Test set uses the last 209 trajectories
#
# Learning (training set of 630 trajectories):
# Model learnt in 0.571 seconds
#
# Testing (test set of 210trajectories):
# Inference on 2_4_1_4.csv test set trajectory
# 2_4_1_4.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.008
# Inference on 1_2_5_1.csv test set trajectory
# 1_2_5_1.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.003
# Inference on 4_1_2_4.csv test set trajectory
# 4_1_2_4.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.003
# Inference on 1_3_2_1.csv test set trajectory
# 1_3_2_1.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.003
# Inference on 3_2_1_3.csv test set trajectory
# 3_2_1_3.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.003
# Inference on 3_1_6_1.csv test set trajectory
# 3_1_6_1.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.002
# Inference on 1_3_6_2.csv test set trajectory
# 1_3_6_2.csv: True Class: 1, Predicted: 1, Probability: 0.6600500182853427, Inference time: 0.001
# Inference on 3_6_5_1.csv test set trajectory
# 3_6_5_1.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.002
# Inference on 4_1_4_5.csv test set trajectory
# 4_1_4_5.csv: True Class: 1, Predicted: 1, Probability: 0.9999999999998741, Inference time: 0.001
# Inference on 4_5_1_3.csv test set trajectory
# 4_5_1_3.csv: True Class: 0, Predicted: 1, Probability: 0.9724223239085841, Inference time: 0.002
# Inference on 3_7_1_4.csv test set trajectory
# 3_7_1_4.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.003
# Inference on 4_3_6_5.csv test set trajectory
# 4_3_6_5.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.001
# Inference on 1_4_4_4.csv test set trajectory
# 1_4_4_4.csv: True Class: 1, Predicted: 1, Probability: 0.999999999763485, Inference time: 0.002
# Inference on 4_1_4_4.csv test set trajectory
# 4_1_4_4.csv: True Class: 1, Predicted: 1, Probability: 0.9999999999998929, Inference time: 0.001
# Inference on 1_7_3_2.csv test set trajectory
# 1_7_3_2.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 2_6_3_1.csv test set trajectory
# 2_6_3_1.csv: True Class: 0, Predicted: 0, Probability: 0.9999999999994704, Inference time: 0.001
# Inference on 1_1_4_5.csv test set trajectory
# 1_1_4_5.csv: True Class: 1, Predicted: 1, Probability: 0.5787323308859117, Inference time: 0.002
# Inference on 3_7_4_1.csv test set trajectory
# 3_7_4_1.csv: True Class: 1, Predicted: 0, Probability: 0.999479253436308, Inference time: 0.001
# Inference on 2_2_3_5.csv test set trajectory
# 2_2_3_5.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 1_5_3_5.csv test set trajectory
# 1_5_3_5.csv: True Class: 0, Predicted: 0, Probability: 0.9999999689751932, Inference time: 0.001
# Inference on 1_1_5_1.csv test set trajectory
# 1_1_5_1.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.001
# Inference on 3_4_5_2.csv test set trajectory
# 3_4_5_2.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.002
# Inference on 3_5_2_4.csv test set trajectory
# 3_5_2_4.csv: True Class: 0, Predicted: 0, Probability: 0.9999999999999925, Inference time: 0.001
# Inference on 1_4_3_4.csv test set trajectory
# 1_4_3_4.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 1_3_6_1.csv test set trajectory
# 1_3_6_1.csv: True Class: 1, Predicted: 0, Probability: 0.9921806155135823, Inference time: 0.001
# Inference on 1_3_4_1.csv test set trajectory
# 1_3_4_1.csv: True Class: 1, Predicted: 0, Probability: 0.9999998945036102, Inference time: 0.001
# Inference on 3_1_1_4.csv test set trajectory
# 3_1_1_4.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.003
# Inference on 2_5_5_1.csv test set trajectory
# 2_5_5_1.csv: True Class: 1, Predicted: 1, Probability: 0.9999999999032256, Inference time: 0.001
# Inference on 3_5_6_3.csv test set trajectory
# 3_5_6_3.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.002
# Inference on 3_3_3_4.csv test set trajectory
# 3_3_3_4.csv: True Class: 0, Predicted: 0, Probability: 0.999999945697836, Inference time: 0.001
# Inference on 2_5_3_4.csv test set trajectory
# 2_5_3_4.csv: True Class: 0, Predicted: 0, Probability: 0.999999999983124, Inference time: 0.001
# Inference on 2_7_1_5.csv test set trajectory
# 2_7_1_5.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.003
# Inference on 1_1_3_2.csv test set trajectory
# 1_1_3_2.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 3_7_2_1.csv test set trajectory
# 3_7_2_1.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 3_2_2_5.csv test set trajectory
# 3_2_2_5.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.002
# Inference on 4_7_5_1.csv test set trajectory
# 4_7_5_1.csv: True Class: 1, Predicted: 1, Probability: 0.9999999999999973, Inference time: 0.001
# Inference on 2_4_5_4.csv test set trajectory
# 2_4_5_4.csv: True Class: 1, Predicted: 1, Probability: 0.9999999999999906, Inference time: 0.001
# Inference on 4_2_3_5.csv test set trajectory
# 4_2_3_5.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 4_2_5_5.csv test set trajectory
# 4_2_5_5.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.001
# Inference on 3_3_5_1.csv test set trajectory
# 3_3_5_1.csv: True Class: 1, Predicted: 1, Probability: 0.9999999999999878, Inference time: 0.001
# Inference on 1_2_3_5.csv test set trajectory
# 1_2_3_5.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 2_5_6_3.csv test set trajectory
# 2_5_6_3.csv: True Class: 1, Predicted: 1, Probability: 0.9999999998720224, Inference time: 0.001
# Inference on 4_6_6_4.csv test set trajectory
# 4_6_6_4.csv: True Class: 1, Predicted: 0, Probability: 1.0, Inference time: 0.002
# Inference on 4_7_3_2.csv test set trajectory
# 4_7_3_2.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 3_2_5_1.csv test set trajectory
# 3_2_5_1.csv: True Class: 1, Predicted: 1, Probability: 0.8493064784132298, Inference time: 0.001
# Inference on 2_7_4_1.csv test set trajectory
# 2_7_4_1.csv: True Class: 1, Predicted: 0, Probability: 0.9999992547082713, Inference time: 0.001
# Inference on 4_1_4_3.csv test set trajectory
# 4_1_4_3.csv: True Class: 1, Predicted: 1, Probability: 0.9999999990068975, Inference time: 0.001
# Inference on 4_3_6_1.csv test set trajectory
# 4_3_6_1.csv: True Class: 1, Predicted: 1, Probability: 0.9999999502374075, Inference time: 0.001
# Inference on 2_4_2_4.csv test set trajectory
# 2_4_2_4.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.002
# Inference on 3_6_5_4.csv test set trajectory
# 3_6_5_4.csv: True Class: 1, Predicted: 1, Probability: 0.9997701498335771, Inference time: 0.001
# Inference on 3_6_6_4.csv test set trajectory
# 3_6_6_4.csv: True Class: 1, Predicted: 1, Probability: 0.999999999999866, Inference time: 0.002
# Inference on 4_2_5_3.csv test set trajectory
# 4_2_5_3.csv: True Class: 1, Predicted: 1, Probability: 0.9999999893615342, Inference time: 0.001
# Inference on 4_7_4_4.csv test set trajectory
# 4_7_4_4.csv: True Class: 1, Predicted: 1, Probability: 0.999999999660228, Inference time: 0.002
# Inference on 4_6_6_1.csv test set trajectory
# 4_6_6_1.csv: True Class: 1, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 3_5_3_3.csv test set trajectory
# 3_5_3_3.csv: True Class: 0, Predicted: 0, Probability: 0.999998381086667, Inference time: 0.001
# Inference on 4_7_2_3.csv test set trajectory
# 4_7_2_3.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.002
# Inference on 4_1_3_4.csv test set trajectory
# 4_1_3_4.csv: True Class: 0, Predicted: 0, Probability: 0.9994933255067658, Inference time: 0.001
# Inference on 3_3_1_4.csv test set trajectory
# 3_3_1_4.csv: True Class: 0, Predicted: 0, Probability: 0.9999998894151997, Inference time: 0.002
# Inference on 4_7_2_4.csv test set trajectory
# 4_7_2_4.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.002
# Inference on 3_3_3_5.csv test set trajectory
# 3_3_3_5.csv: True Class: 0, Predicted: 0, Probability: 0.9999983383689813, Inference time: 0.001
# Inference on 4_1_5_1.csv test set trajectory
# 4_1_5_1.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.001
# Inference on 3_3_3_2.csv test set trajectory
# 3_3_3_2.csv: True Class: 0, Predicted: 0, Probability: 0.9999999999999885, Inference time: 0.001
# Inference on 4_4_4_3.csv test set trajectory
# 4_4_4_3.csv: True Class: 1, Predicted: 1, Probability: 0.9999765877192278, Inference time: 0.001
# Inference on 4_4_6_1.csv test set trajectory
# 4_4_6_1.csv: True Class: 1, Predicted: 1, Probability: 0.9999999999999978, Inference time: 0.001
# Inference on 4_3_4_4.csv test set trajectory
# 4_3_4_4.csv: True Class: 1, Predicted: 1, Probability: 0.9997497983505594, Inference time: 0.001
# Inference on 3_7_2_5.csv test set trajectory
# 3_7_2_5.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.002
# Inference on 1_5_3_2.csv test set trajectory
# 1_5_3_2.csv: True Class: 0, Predicted: 0, Probability: 0.9999999999999998, Inference time: 0.001
# Inference on 4_7_6_4.csv test set trajectory
# 4_7_6_4.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.001
# Inference on 3_5_2_3.csv test set trajectory
# 3_5_2_3.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 4_6_2_5.csv test set trajectory
# 4_6_2_5.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.002
# Inference on 3_6_1_2.csv test set trajectory
# 3_6_1_2.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.002
# Inference on 1_4_3_1.csv test set trajectory
# 1_4_3_1.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 4_4_3_2.csv test set trajectory
# 4_4_3_2.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 1_1_6_1.csv test set trajectory
# 1_1_6_1.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.002
# Inference on 1_1_2_5.csv test set trajectory
# 1_1_2_5.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 1_2_4_3.csv test set trajectory
# 1_2_4_3.csv: True Class: 1, Predicted: 0, Probability: 0.9999999999347428, Inference time: 0.001
# Inference on 1_4_6_2.csv test set trajectory
# 1_4_6_2.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.002
# Inference on 4_5_1_5.csv test set trajectory
# 4_5_1_5.csv: True Class: 0, Predicted: 0, Probability: 0.9999998969146247, Inference time: 0.002
# Inference on 2_2_2_5.csv test set trajectory
# 2_2_2_5.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.002
# Inference on 4_4_1_5.csv test set trajectory
# 4_4_1_5.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.003
# Inference on 1_2_3_2.csv test set trajectory
# 1_2_3_2.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 2_6_4_1.csv test set trajectory
# 2_6_4_1.csv: True Class: 1, Predicted: 1, Probability: 0.6678083249490587, Inference time: 0.001
# Inference on 4_4_3_3.csv test set trajectory
# 4_4_3_3.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 1_5_2_1.csv test set trajectory
# 1_5_2_1.csv: True Class: 0, Predicted: 0, Probability: 0.9999996680771381, Inference time: 0.001
# Inference on 3_4_5_3.csv test set trajectory
# 3_4_5_3.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.002
# Inference on 2_2_5_1.csv test set trajectory
# 2_2_5_1.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.001
# Inference on 4_5_2_3.csv test set trajectory
# 4_5_2_3.csv: True Class: 0, Predicted: 0, Probability: 0.9999765711988212, Inference time: 0.001
# Inference on 1_2_6_4.csv test set trajectory
# 1_2_6_4.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.002
# Inference on 1_6_4_3.csv test set trajectory
# 1_6_4_3.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.001
# Inference on 4_5_2_5.csv test set trajectory
# 4_5_2_5.csv: True Class: 0, Predicted: 0, Probability: 0.9999997341278688, Inference time: 0.001
# Inference on 4_5_6_5.csv test set trajectory
# 4_5_6_5.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.002
# Inference on 1_3_2_2.csv test set trajectory
# 1_3_2_2.csv: True Class: 0, Predicted: 0, Probability: 0.9999999999999999, Inference time: 0.001
# Inference on 3_1_2_3.csv test set trajectory
# 3_1_2_3.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.002
# Inference on 4_7_1_1.csv test set trajectory
# 4_7_1_1.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.002
# Inference on 1_7_6_5.csv test set trajectory
# 1_7_6_5.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.001
# Inference on 3_6_1_5.csv test set trajectory
# 3_6_1_5.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.003
# Inference on 2_4_4_4.csv test set trajectory
# 2_4_4_4.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.002
# Inference on 2_2_3_1.csv test set trajectory
# 2_2_3_1.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 4_6_6_3.csv test set trajectory
# 4_6_6_3.csv: True Class: 1, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 1_3_6_4.csv test set trajectory
# 1_3_6_4.csv: True Class: 1, Predicted: 0, Probability: 1.0, Inference time: 0.002
# Inference on 4_2_3_2.csv test set trajectory
# 4_2_3_2.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 3_7_3_4.csv test set trajectory
# 3_7_3_4.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 2_7_6_5.csv test set trajectory
# 2_7_6_5.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.002
# Inference on 3_3_4_5.csv test set trajectory
# 3_3_4_5.csv: True Class: 1, Predicted: 1, Probability: 0.999999999794247, Inference time: 0.001
# Inference on 4_1_6_3.csv test set trajectory
# 4_1_6_3.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.002
# Inference on 3_1_5_5.csv test set trajectory
# 3_1_5_5.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.001
# Inference on 2_6_1_4.csv test set trajectory
# 2_6_1_4.csv: True Class: 0, Predicted: 1, Probability: 0.9996723912818082, Inference time: 0.002
# Inference on 2_1_1_2.csv test set trajectory
# 2_1_1_2.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.003
# Inference on 2_1_5_3.csv test set trajectory
# 2_1_5_3.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.001
# Inference on 1_2_4_4.csv test set trajectory
# 1_2_4_4.csv: True Class: 1, Predicted: 0, Probability: 0.9999693746765256, Inference time: 0.002
# Inference on 2_4_3_3.csv test set trajectory
# 2_4_3_3.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 3_1_3_5.csv test set trajectory
# 3_1_3_5.csv: True Class: 0, Predicted: 0, Probability: 0.9798574961180326, Inference time: 0.001
# Inference on 1_7_5_3.csv test set trajectory
# 1_7_5_3.csv: True Class: 1, Predicted: 0, Probability: 0.9989094476383313, Inference time: 0.002
# Inference on 3_2_5_3.csv test set trajectory
# 3_2_5_3.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.001
# Inference on 3_2_6_2.csv test set trajectory
# 3_2_6_2.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.001
# Inference on 3_4_5_1.csv test set trajectory
# 3_4_5_1.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.001
# Inference on 1_3_2_5.csv test set trajectory
# 1_3_2_5.csv: True Class: 0, Predicted: 1, Probability: 0.9999991869307758, Inference time: 0.002
# Inference on 2_6_2_5.csv test set trajectory
# 2_6_2_5.csv: True Class: 0, Predicted: 0, Probability: 0.9999998565563557, Inference time: 0.001
# Inference on 2_6_2_2.csv test set trajectory
# 2_6_2_2.csv: True Class: 0, Predicted: 0, Probability: 0.9999999994126327, Inference time: 0.002
# Inference on 2_2_6_2.csv test set trajectory
# 2_2_6_2.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.001
# Inference on 2_3_1_1.csv test set trajectory
# 2_3_1_1.csv: True Class: 0, Predicted: 1, Probability: 1.0, Inference time: 0.002
# Inference on 4_1_6_4.csv test set trajectory
# 4_1_6_4.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.002
# Inference on 1_3_3_2.csv test set trajectory
# 1_3_3_2.csv: True Class: 0, Predicted: 0, Probability: 0.9999525064370707, Inference time: 0.001
# Inference on 4_6_6_2.csv test set trajectory
# 4_6_6_2.csv: True Class: 1, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 2_6_6_2.csv test set trajectory
# 2_6_6_2.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.001
# Inference on 4_3_3_4.csv test set trajectory
# 4_3_3_4.csv: True Class: 0, Predicted: 0, Probability: 0.7543106903146973, Inference time: 0.002
# Inference on 4_3_4_5.csv test set trajectory
# 4_3_4_5.csv: True Class: 1, Predicted: 1, Probability: 0.9999999998121125, Inference time: 0.001
# Inference on 2_1_6_5.csv test set trajectory
# 2_1_6_5.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.001
# Inference on 1_4_1_1.csv test set trajectory
# 1_4_1_1.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.003
# Inference on 1_3_2_3.csv test set trajectory
# 1_3_2_3.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.002
# Inference on 2_2_3_3.csv test set trajectory
# 2_2_3_3.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 2_5_4_2.csv test set trajectory
# 2_5_4_2.csv: True Class: 1, Predicted: 0, Probability: 0.9162853502410208, Inference time: 0.001
# Inference on 2_7_1_1.csv test set trajectory
# 2_7_1_1.csv: True Class: 0, Predicted: 1, Probability: 0.0, Inference time: 0.002
# Inference on 1_7_5_1.csv test set trajectory
# 1_7_5_1.csv: True Class: 1, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 4_2_5_4.csv test set trajectory
# 4_2_5_4.csv: True Class: 1, Predicted: 1, Probability: 0.9999999999965029, Inference time: 0.002
# Inference on 2_4_6_4.csv test set trajectory
# 2_4_6_4.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.001
# Inference on 2_3_2_1.csv test set trajectory
# 2_3_2_1.csv: True Class: 0, Predicted: 1, Probability: 0.999999999916265, Inference time: 0.002
# Inference on 1_5_4_1.csv test set trajectory
# 1_5_4_1.csv: True Class: 1, Predicted: 0, Probability: 0.9922339495900572, Inference time: 0.001
# Inference on 1_5_4_4.csv test set trajectory
# 1_5_4_4.csv: True Class: 1, Predicted: 1, Probability: 0.9985878596716944, Inference time: 0.001
# Inference on 3_3_5_3.csv test set trajectory
# 3_3_5_3.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.001
# Inference on 4_7_5_5.csv test set trajectory
# 4_7_5_5.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.002
# Inference on 2_7_5_2.csv test set trajectory
# 2_7_5_2.csv: True Class: 1, Predicted: 1, Probability: 0.9750494285058987, Inference time: 0.002
# Inference on 3_6_6_3.csv test set trajectory
# 3_6_6_3.csv: True Class: 1, Predicted: 1, Probability: 0.9999999886752499, Inference time: 0.001
# Inference on 4_4_2_1.csv test set trajectory
# 4_4_2_1.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 1_3_5_1.csv test set trajectory
# 1_3_5_1.csv: True Class: 1, Predicted: 0, Probability: 0.9999999517312429, Inference time: 0.001
# Inference on 2_3_5_4.csv test set trajectory
# 2_3_5_4.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.001
# Inference on 3_6_1_4.csv test set trajectory
# 3_6_1_4.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.003
# Inference on 3_5_3_4.csv test set trajectory
# 3_5_3_4.csv: True Class: 0, Predicted: 0, Probability: 0.9999999145329301, Inference time: 0.001
# Inference on 2_4_2_5.csv test set trajectory
# 2_4_2_5.csv: True Class: 0, Predicted: 0, Probability: 0.9999999999998571, Inference time: 0.001
# Inference on 2_5_1_1.csv test set trajectory
# 2_5_1_1.csv: True Class: 0, Predicted: 1, Probability: 1.0, Inference time: 0.002
# Inference on 4_1_2_3.csv test set trajectory
# 4_1_2_3.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 1_6_2_4.csv test set trajectory
# 1_6_2_4.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.002
# Inference on 1_1_6_3.csv test set trajectory
# 1_1_6_3.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.001
# Inference on 3_5_1_4.csv test set trajectory
# 3_5_1_4.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.002
# Inference on 1_1_4_2.csv test set trajectory
# 1_1_4_2.csv: True Class: 1, Predicted: 0, Probability: 0.999953965549081, Inference time: 0.002
# Inference on 4_6_1_2.csv test set trajectory
# 4_6_1_2.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.002
# Inference on 2_3_5_3.csv test set trajectory
# 2_3_5_3.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.001
# Inference on 1_7_4_4.csv test set trajectory
# 1_7_4_4.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.002
# Inference on 1_5_1_2.csv test set trajectory
# 1_5_1_2.csv: True Class: 0, Predicted: 0, Probability: 0.9999999999999917, Inference time: 0.002
# Inference on 4_3_6_3.csv test set trajectory
# 4_3_6_3.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.002
# Inference on 3_3_6_1.csv test set trajectory
# 3_3_6_1.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.001
# Inference on 1_7_1_1.csv test set trajectory
# 1_7_1_1.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.003
# Inference on 2_1_4_1.csv test set trajectory
# 2_1_4_1.csv: True Class: 1, Predicted: 1, Probability: 0.9999999999983333, Inference time: 0.001
# Inference on 2_2_5_2.csv test set trajectory
# 2_2_5_2.csv: True Class: 1, Predicted: 1, Probability: 0.9999999999999838, Inference time: 0.002
# Inference on 3_7_3_3.csv test set trajectory
# 3_7_3_3.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 3_1_5_1.csv test set trajectory
# 3_1_5_1.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.001
# Inference on 1_1_3_4.csv test set trajectory
# 1_1_3_4.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.002
# Inference on 1_5_4_3.csv test set trajectory
# 1_5_4_3.csv: True Class: 1, Predicted: 1, Probability: 0.8712586737263661, Inference time: 0.001
# Inference on 3_4_4_3.csv test set trajectory
# 3_4_4_3.csv: True Class: 1, Predicted: 1, Probability: 0.9984673477012898, Inference time: 0.001
# Inference on 4_2_3_4.csv test set trajectory
# 4_2_3_4.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 2_5_4_3.csv test set trajectory
# 2_5_4_3.csv: True Class: 1, Predicted: 1, Probability: 0.9991437516440336, Inference time: 0.001
# Inference on 2_7_1_2.csv test set trajectory
# 2_7_1_2.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.002
# Inference on 2_5_2_1.csv test set trajectory
# 2_5_2_1.csv: True Class: 0, Predicted: 0, Probability: 0.9999999999787652, Inference time: 0.002
# Inference on 3_2_5_2.csv test set trajectory
# 3_2_5_2.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.001
# Inference on 1_3_5_5.csv test set trajectory
# 1_3_5_5.csv: True Class: 1, Predicted: 0, Probability: 0.9998045259879306, Inference time: 0.001
# Inference on 4_7_2_5.csv test set trajectory
# 4_7_2_5.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.002
# Inference on 2_5_6_2.csv test set trajectory
# 2_5_6_2.csv: True Class: 1, Predicted: 1, Probability: 0.9999999999509734, Inference time: 0.001
# Inference on 1_3_5_2.csv test set trajectory
# 1_3_5_2.csv: True Class: 1, Predicted: 1, Probability: 0.9999994861684582, Inference time: 0.001
# Inference on 1_2_5_3.csv test set trajectory
# 1_2_5_3.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.002
# Inference on 3_1_6_4.csv test set trajectory
# 3_1_6_4.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.001
# Inference on 4_2_2_4.csv test set trajectory
# 4_2_2_4.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 1_5_6_5.csv test set trajectory
# 1_5_6_5.csv: True Class: 1, Predicted: 1, Probability: 0.9999999999974152, Inference time: 0.002
# Inference on 3_7_3_2.csv test set trajectory
# 3_7_3_2.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 3_2_1_2.csv test set trajectory
# 3_2_1_2.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.003
# Inference on 1_6_4_2.csv test set trajectory
# 1_6_4_2.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.001
# Inference on 1_7_4_2.csv test set trajectory
# 1_7_4_2.csv: True Class: 1, Predicted: 0, Probability: 0.9999399285418534, Inference time: 0.001
# Inference on 1_6_6_3.csv test set trajectory
# 1_6_6_3.csv: True Class: 1, Predicted: 0, Probability: 0.9999999999999977, Inference time: 0.002
# Inference on 3_6_3_4.csv test set trajectory
# 3_6_3_4.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 3_1_3_3.csv test set trajectory
# 3_1_3_3.csv: True Class: 0, Predicted: 0, Probability: 0.9991315140666202, Inference time: 0.001
# Inference on 3_2_2_2.csv test set trajectory
# 3_2_2_2.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 3_4_3_1.csv test set trajectory
# 3_4_3_1.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 3_3_6_3.csv test set trajectory
# 3_3_6_3.csv: True Class: 1, Predicted: 1, Probability: 0.9999999999999948, Inference time: 0.002
# Inference on 3_2_3_2.csv test set trajectory
# 3_2_3_2.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 2_3_4_4.csv test set trajectory
# 2_3_4_4.csv: True Class: 1, Predicted: 1, Probability: 0.9999997327897363, Inference time: 0.001
# Inference on 1_1_5_5.csv test set trajectory
# 1_1_5_5.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.002
# Inference on 4_6_5_1.csv test set trajectory
# 4_6_5_1.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.001
# Inference on 1_6_2_2.csv test set trajectory
# 1_6_2_2.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 1_6_2_5.csv test set trajectory
# 1_6_2_5.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.002
# Inference on 2_3_1_5.csv test set trajectory
# 2_3_1_5.csv: True Class: 0, Predicted: 1, Probability: 1.0, Inference time: 0.002
# Inference on 2_3_1_3.csv test set trajectory
# 2_3_1_3.csv: True Class: 0, Predicted: 1, Probability: 1.0, Inference time: 0.002
# Inference on 3_3_5_5.csv test set trajectory
# 3_3_5_5.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.002
# Inference on 3_5_4_5.csv test set trajectory
# 3_5_4_5.csv: True Class: 1, Predicted: 1, Probability: 0.9999999999997429, Inference time: 0.001
# Inference on 3_7_5_1.csv test set trajectory
# 3_7_5_1.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.001
# Inference on 1_5_3_1.csv test set trajectory
# 1_5_3_1.csv: True Class: 0, Predicted: 0, Probability: 0.9999999999999004, Inference time: 0.001
# Inference on 1_7_1_3.csv test set trajectory
# 1_7_1_3.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.002
# Inference on 1_1_1_3.csv test set trajectory
# 1_1_1_3.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.003
# Inference on 1_5_5_3.csv test set trajectory
# 1_5_5_3.csv: True Class: 1, Predicted: 1, Probability: 0.9994421088834986, Inference time: 0.001
# Inference on 4_7_2_2.csv test set trajectory
# 4_7_2_2.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.002
# Inference on 3_7_4_4.csv test set trajectory
# 3_7_4_4.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.001
# Inference on 2_1_6_3.csv test set trajectory
# 2_1_6_3.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.001
# 	. result printing
#
# M0_CTNB results printing
# Execute tests (END)
#
# Comparison tests:
#
# Comparison tests (END)

# %% [markdown]
# ### Since it works with independent labels, we already have binary relevance implemented. So now let's focus on implementing a chain of classifiers

# %%
inDir = os.path.join('data', 'rehab')
outDir = os.path.join('results', 'extra')

# %%
# !java -jar CTBNCToolkit.jar --v --CTBNC=CTNB --validation=HO,0.75 --validColumns=S1,S2,S3,S4,S5,S6,S7,S8,S9,S10,S11,S12,S13,S14,S15,S16,S17,S18,S19,S20,S21,S22,S23,S24,S25,S26,S27,S28,S29,Exercise --timeName=t --className=ExerciseMode --rPath={outDir} {inDir}
# Out:
# Datasets generation:
#
# 	. single dataset loading
#
# 	. dataset permutation
#
# 	. dataset dimension cutting (% = 1.0)
#
# Datasets generation (END)
#
# Learning algorithms generation:
#
# 	. model 0: CTNB
#
# 		. Mxx_prior = 1.0
#
# 		. Tx_prior = 0.005
#
# 		. Px_prior = 1.0
#
# 		. generation of classification parameter learning algorithm
#
# Learning algorithms generation (END)
#
# Inference algorithm generation:
#
# 	. probabilities = true
#
# 	. binary class decider = disabled
#
# 	. classification algorithm
#
# Inference algorithm generation (END)
#
# Hold out
#
# Test factories generation:
#
# 	. model CTNB
#
# Test factories generation (END)
#
# Execute tests:
#
# 	. model M0_CTNB
#
# 	. test running
#
#
#
# Hold out schema (cut = 0.75)
# Training set uses the first 630 trajectories
# Test set uses the last 209 trajectories
#
# Learning (training set of 630 trajectories):
# Model learnt in 0.63 seconds
#
# Testing (test set of 210trajectories):
# Inference on 4_1_1_1.csv test set trajectory
# 4_1_1_1.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.009
# Inference on 4_1_1_2.csv test set trajectory
# 4_1_1_2.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.007
# Inference on 4_1_1_3.csv test set trajectory
# 4_1_1_3.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.003
# Inference on 4_1_1_4.csv test set trajectory
# 4_1_1_4.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.003
# Inference on 4_1_1_5.csv test set trajectory
# 4_1_1_5.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.003
# Inference on 4_1_2_1.csv test set trajectory
# 4_1_2_1.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 4_1_2_2.csv test set trajectory
# 4_1_2_2.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 4_1_2_3.csv test set trajectory
# 4_1_2_3.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 4_1_2_4.csv test set trajectory
# 4_1_2_4.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.002
# Inference on 4_1_2_5.csv test set trajectory
# 4_1_2_5.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 4_1_3_1.csv test set trajectory
# 4_1_3_1.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 4_1_3_2.csv test set trajectory
# 4_1_3_2.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 4_1_3_3.csv test set trajectory
# 4_1_3_3.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 4_1_3_4.csv test set trajectory
# 4_1_3_4.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 4_1_3_5.csv test set trajectory
# 4_1_3_5.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 4_1_4_1.csv test set trajectory
# 4_1_4_1.csv: True Class: 1, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 4_1_4_2.csv test set trajectory
# 4_1_4_2.csv: True Class: 1, Predicted: 0, Probability: 1.0, Inference time: 0.002
# Inference on 4_1_4_3.csv test set trajectory
# 4_1_4_3.csv: True Class: 1, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 4_1_4_4.csv test set trajectory
# 4_1_4_4.csv: True Class: 1, Predicted: 0, Probability: 1.0, Inference time: 0.002
# Inference on 4_1_4_5.csv test set trajectory
# 4_1_4_5.csv: True Class: 1, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 4_1_5_1.csv test set trajectory
# 4_1_5_1.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.001
# Inference on 4_1_5_2.csv test set trajectory
# 4_1_5_2.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.002
# Inference on 4_1_5_3.csv test set trajectory
# 4_1_5_3.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.001
# Inference on 4_1_5_4.csv test set trajectory
# 4_1_5_4.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.001
# Inference on 4_1_5_5.csv test set trajectory
# 4_1_5_5.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.002
# Inference on 4_1_6_1.csv test set trajectory
# 4_1_6_1.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.002
# Inference on 4_1_6_2.csv test set trajectory
# 4_1_6_2.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.002
# Inference on 4_1_6_3.csv test set trajectory
# 4_1_6_3.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.001
# Inference on 4_1_6_4.csv test set trajectory
# 4_1_6_4.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.002
# Inference on 4_1_6_5.csv test set trajectory
# 4_1_6_5.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.001
# Inference on 4_2_1_1.csv test set trajectory
# 4_2_1_1.csv: True Class: 0, Predicted: 1, Probability: 1.0, Inference time: 0.003
# Inference on 4_2_1_2.csv test set trajectory
# 4_2_1_2.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.003
# Inference on 4_2_1_3.csv test set trajectory
# 4_2_1_3.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.003
# Inference on 4_2_1_4.csv test set trajectory
# 4_2_1_4.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.002
# Inference on 4_2_1_5.csv test set trajectory
# 4_2_1_5.csv: True Class: 0, Predicted: 1, Probability: 0.9999999989641385, Inference time: 0.003
# Inference on 4_2_2_1.csv test set trajectory
# 4_2_2_1.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 4_2_2_2.csv test set trajectory
# 4_2_2_2.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.002
# Inference on 4_2_2_3.csv test set trajectory
# 4_2_2_3.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 4_2_2_4.csv test set trajectory
# 4_2_2_4.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 4_2_2_5.csv test set trajectory
# 4_2_2_5.csv: True Class: 0, Predicted: 1, Probability: 0.9999699289686699, Inference time: 0.001
# Inference on 4_2_3_1.csv test set trajectory
# 4_2_3_1.csv: True Class: 0, Predicted: 1, Probability: 0.9999999999929807, Inference time: 0.001
# Inference on 4_2_3_2.csv test set trajectory
# 4_2_3_2.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 4_2_3_3.csv test set trajectory
# 4_2_3_3.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 4_2_3_4.csv test set trajectory
# 4_2_3_4.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 4_2_3_5.csv test set trajectory
# 4_2_3_5.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 4_2_4_1.csv test set trajectory
# 4_2_4_1.csv: True Class: 1, Predicted: 1, Probability: 0.9999999933429627, Inference time: 0.001
# Inference on 4_2_4_2.csv test set trajectory
# 4_2_4_2.csv: True Class: 1, Predicted: 0, Probability: 0.9999897502992572, Inference time: 0.002
# Inference on 4_2_4_3.csv test set trajectory
# 4_2_4_3.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.001
# Inference on 4_2_4_4.csv test set trajectory
# 4_2_4_4.csv: True Class: 1, Predicted: 1, Probability: 0.9999999999989713, Inference time: 0.001
# Inference on 4_2_4_5.csv test set trajectory
# 4_2_4_5.csv: True Class: 1, Predicted: 1, Probability: 0.9999999999999234, Inference time: 0.002
# Inference on 4_2_5_1.csv test set trajectory
# 4_2_5_1.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.001
# Inference on 4_2_5_2.csv test set trajectory
# 4_2_5_2.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.001
# Inference on 4_2_5_3.csv test set trajectory
# 4_2_5_3.csv: True Class: 1, Predicted: 1, Probability: 0.9999999999854237, Inference time: 0.002
# Inference on 4_2_5_4.csv test set trajectory
# 4_2_5_4.csv: True Class: 1, Predicted: 1, Probability: 0.9999999999999241, Inference time: 0.001
# Inference on 4_2_5_5.csv test set trajectory
# 4_2_5_5.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.002
# Inference on 4_2_6_1.csv test set trajectory
# 4_2_6_1.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.001
# Inference on 4_2_6_2.csv test set trajectory
# 4_2_6_2.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.001
# Inference on 4_2_6_3.csv test set trajectory
# 4_2_6_3.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.002
# Inference on 4_2_6_4.csv test set trajectory
# 4_2_6_4.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.001
# Inference on 4_2_6_5.csv test set trajectory
# 4_2_6_5.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.002
# Inference on 4_3_1_1.csv test set trajectory
# 4_3_1_1.csv: True Class: 0, Predicted: 1, Probability: 1.0, Inference time: 0.002
# Inference on 4_3_1_2.csv test set trajectory
# 4_3_1_2.csv: True Class: 0, Predicted: 1, Probability: 0.9999999999996155, Inference time: 0.002
# Inference on 4_3_1_3.csv test set trajectory
# 4_3_1_3.csv: True Class: 0, Predicted: 0, Probability: 0.5809568588189802, Inference time: 0.002
# Inference on 4_3_1_4.csv test set trajectory
# 4_3_1_4.csv: True Class: 0, Predicted: 1, Probability: 0.9999987178223405, Inference time: 0.002
# Inference on 4_3_1_5.csv test set trajectory
# 4_3_1_5.csv: True Class: 0, Predicted: 1, Probability: 1.0, Inference time: 0.002
# Inference on 4_3_2_1.csv test set trajectory
# 4_3_2_1.csv: True Class: 0, Predicted: 1, Probability: 0.9999999999999998, Inference time: 0.001
# Inference on 4_3_2_2.csv test set trajectory
# 4_3_2_2.csv: True Class: 0, Predicted: 1, Probability: 1.0, Inference time: 0.002
# Inference on 4_3_2_3.csv test set trajectory
# 4_3_2_3.csv: True Class: 0, Predicted: 1, Probability: 0.9999999999879264, Inference time: 0.001
# Inference on 4_3_2_4.csv test set trajectory
# 4_3_2_4.csv: True Class: 0, Predicted: 1, Probability: 0.9999999999999998, Inference time: 0.002
# Inference on 4_3_2_5.csv test set trajectory
# 4_3_2_5.csv: True Class: 0, Predicted: 1, Probability: 0.999999999227874, Inference time: 0.001
# Inference on 4_3_3_1.csv test set trajectory
# 4_3_3_1.csv: True Class: 0, Predicted: 1, Probability: 0.9999557160767746, Inference time: 0.001
# Inference on 4_3_3_2.csv test set trajectory
# 4_3_3_2.csv: True Class: 0, Predicted: 1, Probability: 0.9999990536993157, Inference time: 0.001
# Inference on 4_3_3_3.csv test set trajectory
# 4_3_3_3.csv: True Class: 0, Predicted: 1, Probability: 0.9999676836755184, Inference time: 0.001
# Inference on 4_3_3_4.csv test set trajectory
# 4_3_3_4.csv: True Class: 0, Predicted: 1, Probability: 0.9999999964057434, Inference time: 0.001
# Inference on 4_3_3_5.csv test set trajectory
# 4_3_3_5.csv: True Class: 0, Predicted: 1, Probability: 0.9999999996718602, Inference time: 0.001
# Inference on 4_3_4_1.csv test set trajectory
# 4_3_4_1.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.001
# Inference on 4_3_4_2.csv test set trajectory
# 4_3_4_2.csv: True Class: 1, Predicted: 1, Probability: 0.9999999999998759, Inference time: 0.001
# Inference on 4_3_4_3.csv test set trajectory
# 4_3_4_3.csv: True Class: 1, Predicted: 1, Probability: 0.9999999999999993, Inference time: 0.002
# Inference on 4_3_4_4.csv test set trajectory
# 4_3_4_4.csv: True Class: 1, Predicted: 1, Probability: 0.9997868842884595, Inference time: 0.001
# Inference on 4_3_4_5.csv test set trajectory
# 4_3_4_5.csv: True Class: 1, Predicted: 1, Probability: 0.9999999999442784, Inference time: 0.001
# Inference on 4_3_5_1.csv test set trajectory
# 4_3_5_1.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.001
# Inference on 4_3_5_2.csv test set trajectory
# 4_3_5_2.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.001
# Inference on 4_3_5_3.csv test set trajectory
# 4_3_5_3.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.002
# Inference on 4_3_5_4.csv test set trajectory
# 4_3_5_4.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.001
# Inference on 4_3_5_5.csv test set trajectory
# 4_3_5_5.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.001
# Inference on 4_3_6_1.csv test set trajectory
# 4_3_6_1.csv: True Class: 1, Predicted: 1, Probability: 0.9999998528207038, Inference time: 0.001
# Inference on 4_3_6_2.csv test set trajectory
# 4_3_6_2.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.001
# Inference on 4_3_6_3.csv test set trajectory
# 4_3_6_3.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.002
# Inference on 4_3_6_4.csv test set trajectory
# 4_3_6_4.csv: True Class: 1, Predicted: 1, Probability: 0.9999999998769613, Inference time: 0.001
# Inference on 4_3_6_5.csv test set trajectory
# 4_3_6_5.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.001
# Inference on 4_4_1_1.csv test set trajectory
# 4_4_1_1.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.003
# Inference on 4_4_1_2.csv test set trajectory
# 4_4_1_2.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.002
# Inference on 4_4_1_3.csv test set trajectory
# 4_4_1_3.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.002
# Inference on 4_4_1_4.csv test set trajectory
# 4_4_1_4.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.002
# Inference on 4_4_1_5.csv test set trajectory
# 4_4_1_5.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.003
# Inference on 4_4_2_1.csv test set trajectory
# 4_4_2_1.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 4_4_2_2.csv test set trajectory
# 4_4_2_2.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.002
# Inference on 4_4_2_3.csv test set trajectory
# 4_4_2_3.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 4_4_2_4.csv test set trajectory
# 4_4_2_4.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.002
# Inference on 4_4_2_5.csv test set trajectory
# 4_4_2_5.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 4_4_3_1.csv test set trajectory
# 4_4_3_1.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 4_4_3_2.csv test set trajectory
# 4_4_3_2.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 4_4_3_3.csv test set trajectory
# 4_4_3_3.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 4_4_3_4.csv test set trajectory
# 4_4_3_4.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 4_4_3_5.csv test set trajectory
# 4_4_3_5.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 4_4_4_1.csv test set trajectory
# 4_4_4_1.csv: True Class: 1, Predicted: 1, Probability: 0.9700894898428319, Inference time: 0.001
# Inference on 4_4_4_2.csv test set trajectory
# 4_4_4_2.csv: True Class: 1, Predicted: 1, Probability: 0.9973496440492496, Inference time: 0.001
# Inference on 4_4_4_3.csv test set trajectory
# 4_4_4_3.csv: True Class: 1, Predicted: 1, Probability: 0.9986379327989613, Inference time: 0.002
# Inference on 4_4_4_4.csv test set trajectory
# 4_4_4_4.csv: True Class: 1, Predicted: 1, Probability: 0.9994189355023979, Inference time: 0.001
# Inference on 4_4_4_5.csv test set trajectory
# 4_4_4_5.csv: True Class: 1, Predicted: 1, Probability: 0.9703320845953705, Inference time: 0.001
# Inference on 4_4_5_1.csv test set trajectory
# 4_4_5_1.csv: True Class: 1, Predicted: 1, Probability: 0.9999999999999987, Inference time: 0.001
# Inference on 4_4_5_2.csv test set trajectory
# 4_4_5_2.csv: True Class: 1, Predicted: 1, Probability: 0.9999986533127979, Inference time: 0.001
# Inference on 4_4_5_3.csv test set trajectory
# 4_4_5_3.csv: True Class: 1, Predicted: 1, Probability: 0.9809293672844192, Inference time: 0.001
# Inference on 4_4_5_4.csv test set trajectory
# 4_4_5_4.csv: True Class: 1, Predicted: 1, Probability: 0.9979156860686688, Inference time: 0.002
# Inference on 4_4_5_5.csv test set trajectory
# 4_4_5_5.csv: True Class: 1, Predicted: 1, Probability: 0.9957839136637482, Inference time: 0.001
# Inference on 4_4_6_1.csv test set trajectory
# 4_4_6_1.csv: True Class: 1, Predicted: 1, Probability: 0.9999999993801201, Inference time: 0.001
# Inference on 4_4_6_2.csv test set trajectory
# 4_4_6_2.csv: True Class: 1, Predicted: 1, Probability: 0.9999886755405893, Inference time: 0.001
# Inference on 4_4_6_3.csv test set trajectory
# 4_4_6_3.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.002
# Inference on 4_4_6_4.csv test set trajectory
# 4_4_6_4.csv: True Class: 1, Predicted: 1, Probability: 0.9999999881706046, Inference time: 0.001
# Inference on 4_4_6_5.csv test set trajectory
# 4_4_6_5.csv: True Class: 1, Predicted: 1, Probability: 0.9593135277596742, Inference time: 0.001
# Inference on 4_5_1_1.csv test set trajectory
# 4_5_1_1.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.003
# Inference on 4_5_1_2.csv test set trajectory
# 4_5_1_2.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.002
# Inference on 4_5_1_3.csv test set trajectory
# 4_5_1_3.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.002
# Inference on 4_5_1_4.csv test set trajectory
# 4_5_1_4.csv: True Class: 0, Predicted: 1, Probability: 0.9999999913633418, Inference time: 0.001
# Inference on 4_5_1_5.csv test set trajectory
# 4_5_1_5.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.002
# Inference on 4_5_2_1.csv test set trajectory
# 4_5_2_1.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.002
# Inference on 4_5_2_2.csv test set trajectory
# 4_5_2_2.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 4_5_2_3.csv test set trajectory
# 4_5_2_3.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 4_5_2_4.csv test set trajectory
# 4_5_2_4.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 4_5_2_5.csv test set trajectory
# 4_5_2_5.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 4_5_3_1.csv test set trajectory
# 4_5_3_1.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 4_5_3_2.csv test set trajectory
# 4_5_3_2.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 4_5_3_3.csv test set trajectory
# 4_5_3_3.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 4_5_3_4.csv test set trajectory
# 4_5_3_4.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 4_5_3_5.csv test set trajectory
# 4_5_3_5.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 4_5_4_1.csv test set trajectory
# 4_5_4_1.csv: True Class: 1, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 4_5_4_2.csv test set trajectory
# 4_5_4_2.csv: True Class: 1, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 4_5_4_3.csv test set trajectory
# 4_5_4_3.csv: True Class: 1, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 4_5_4_4.csv test set trajectory
# 4_5_4_4.csv: True Class: 1, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 4_5_4_5.csv test set trajectory
# 4_5_4_5.csv: True Class: 1, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 4_5_5_1.csv test set trajectory
# 4_5_5_1.csv: True Class: 1, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 4_5_5_2.csv test set trajectory
# 4_5_5_2.csv: True Class: 1, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 4_5_5_3.csv test set trajectory
# 4_5_5_3.csv: True Class: 1, Predicted: 0, Probability: 1.0, Inference time: 0.002
# Inference on 4_5_5_4.csv test set trajectory
# 4_5_5_4.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.001
# Inference on 4_5_5_5.csv test set trajectory
# 4_5_5_5.csv: True Class: 1, Predicted: 0, Probability: 0.0, Inference time: 0.001
# Inference on 4_5_6_1.csv test set trajectory
# 4_5_6_1.csv: True Class: 1, Predicted: 1, Probability: 0.0, Inference time: 0.001
# Inference on 4_5_6_2.csv test set trajectory
# 4_5_6_2.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.001
# Inference on 4_5_6_3.csv test set trajectory
# 4_5_6_3.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.001
# Inference on 4_5_6_4.csv test set trajectory
# 4_5_6_4.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.002
# Inference on 4_5_6_5.csv test set trajectory
# 4_5_6_5.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.001
# Inference on 4_6_1_1.csv test set trajectory
# 4_6_1_1.csv: True Class: 0, Predicted: 1, Probability: 1.0, Inference time: 0.002
# Inference on 4_6_1_2.csv test set trajectory
# 4_6_1_2.csv: True Class: 0, Predicted: 1, Probability: 1.0, Inference time: 0.002
# Inference on 4_6_1_3.csv test set trajectory
# 4_6_1_3.csv: True Class: 0, Predicted: 1, Probability: 1.0, Inference time: 0.002
# Inference on 4_6_1_4.csv test set trajectory
# 4_6_1_4.csv: True Class: 0, Predicted: 1, Probability: 1.0, Inference time: 0.002
# Inference on 4_6_1_5.csv test set trajectory
# 4_6_1_5.csv: True Class: 0, Predicted: 1, Probability: 1.0, Inference time: 0.002
# Inference on 4_6_2_1.csv test set trajectory
# 4_6_2_1.csv: True Class: 0, Predicted: 1, Probability: 0.0, Inference time: 0.001
# Inference on 4_6_2_2.csv test set trajectory
# 4_6_2_2.csv: True Class: 0, Predicted: 1, Probability: 0.0, Inference time: 0.001
# Inference on 4_6_2_3.csv test set trajectory
# 4_6_2_3.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 4_6_2_4.csv test set trajectory
# 4_6_2_4.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.002
# Inference on 4_6_2_5.csv test set trajectory
# 4_6_2_5.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 4_6_3_1.csv test set trajectory
# 4_6_3_1.csv: True Class: 0, Predicted: 1, Probability: 0.9999999999989639, Inference time: 0.001
# Inference on 4_6_3_2.csv test set trajectory
# 4_6_3_2.csv: True Class: 0, Predicted: 1, Probability: 1.0, Inference time: 0.001
# Inference on 4_6_3_3.csv test set trajectory
# 4_6_3_3.csv: True Class: 0, Predicted: 1, Probability: 0.9999999999998739, Inference time: 0.001
# Inference on 4_6_3_4.csv test set trajectory
# 4_6_3_4.csv: True Class: 0, Predicted: 1, Probability: 1.0, Inference time: 0.001
# Inference on 4_6_3_5.csv test set trajectory
# 4_6_3_5.csv: True Class: 0, Predicted: 1, Probability: 0.9999980113991989, Inference time: 0.001
# Inference on 4_6_4_1.csv test set trajectory
# 4_6_4_1.csv: True Class: 1, Predicted: 1, Probability: 0.9999317263149154, Inference time: 0.001
# Inference on 4_6_4_2.csv test set trajectory
# 4_6_4_2.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.001
# Inference on 4_6_4_3.csv test set trajectory
# 4_6_4_3.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.002
# Inference on 4_6_4_4.csv test set trajectory
# 4_6_4_4.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.001
# Inference on 4_6_4_5.csv test set trajectory
# 4_6_4_5.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.002
# Inference on 4_6_5_1.csv test set trajectory
# 4_6_5_1.csv: True Class: 1, Predicted: 1, Probability: 0.9993621450684834, Inference time: 0.001
# Inference on 4_6_5_2.csv test set trajectory
# 4_6_5_2.csv: True Class: 1, Predicted: 1, Probability: 0.7642833472470801, Inference time: 0.001
# Inference on 4_6_5_3.csv test set trajectory
# 4_6_5_3.csv: True Class: 1, Predicted: 1, Probability: 0.9999995750586349, Inference time: 0.002
# Inference on 4_6_5_4.csv test set trajectory
# 4_6_5_4.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.001
# Inference on 4_6_5_5.csv test set trajectory
# 4_6_5_5.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.001
# Inference on 4_6_6_1.csv test set trajectory
# 4_6_6_1.csv: True Class: 1, Predicted: 0, Probability: 1.0, Inference time: 0.002
# Inference on 4_6_6_2.csv test set trajectory
# 4_6_6_2.csv: True Class: 1, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 4_6_6_3.csv test set trajectory
# 4_6_6_3.csv: True Class: 1, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 4_6_6_4.csv test set trajectory
# 4_6_6_4.csv: True Class: 1, Predicted: 0, Probability: 1.0, Inference time: 0.002
# Inference on 4_6_6_5.csv test set trajectory
# 4_6_6_5.csv: True Class: 1, Predicted: 0, Probability: 1.0, Inference time: 0.002
# Inference on 4_7_1_1.csv test set trajectory
# 4_7_1_1.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.002
# Inference on 4_7_1_2.csv test set trajectory
# 4_7_1_2.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.002
# Inference on 4_7_1_3.csv test set trajectory
# 4_7_1_3.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.002
# Inference on 4_7_1_4.csv test set trajectory
# 4_7_1_4.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.002
# Inference on 4_7_1_5.csv test set trajectory
# 4_7_1_5.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.002
# Inference on 4_7_2_1.csv test set trajectory
# 4_7_2_1.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 4_7_2_2.csv test set trajectory
# 4_7_2_2.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 4_7_2_3.csv test set trajectory
# 4_7_2_3.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 4_7_2_4.csv test set trajectory
# 4_7_2_4.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 4_7_2_5.csv test set trajectory
# 4_7_2_5.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.002
# Inference on 4_7_3_1.csv test set trajectory
# 4_7_3_1.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.0
# Inference on 4_7_3_2.csv test set trajectory
# 4_7_3_2.csv: True Class: 0, Predicted: 0, Probability: 1.0, Inference time: 0.002
# Inference on 4_7_3_3.csv test set trajectory
# 4_7_3_3.csv: True Class: 0, Predicted: 1, Probability: 0.9999999741574374, Inference time: 0.001
# Inference on 4_7_3_4.csv test set trajectory
# 4_7_3_4.csv: True Class: 0, Predicted: 1, Probability: 1.0, Inference time: 0.001
# Inference on 4_7_3_5.csv test set trajectory
# 4_7_3_5.csv: True Class: 0, Predicted: 1, Probability: 0.9999993926226944, Inference time: 0.001
# Inference on 4_7_4_1.csv test set trajectory
# 4_7_4_1.csv: True Class: 1, Predicted: 0, Probability: 0.999999999999118, Inference time: 0.001
# Inference on 4_7_4_2.csv test set trajectory
# 4_7_4_2.csv: True Class: 1, Predicted: 1, Probability: 0.7803092012331205, Inference time: 0.001
# Inference on 4_7_4_3.csv test set trajectory
# 4_7_4_3.csv: True Class: 1, Predicted: 0, Probability: 0.9994248844282265, Inference time: 0.002
# Inference on 4_7_4_4.csv test set trajectory
# 4_7_4_4.csv: True Class: 1, Predicted: 0, Probability: 0.9998357316997575, Inference time: 0.002
# Inference on 4_7_4_5.csv test set trajectory
# 4_7_4_5.csv: True Class: 1, Predicted: 0, Probability: 1.0, Inference time: 0.001
# Inference on 4_7_5_1.csv test set trajectory
# 4_7_5_1.csv: True Class: 1, Predicted: 1, Probability: 0.999997925050605, Inference time: 0.002
# Inference on 4_7_5_2.csv test set trajectory
# 4_7_5_2.csv: True Class: 1, Predicted: 1, Probability: 0.9999999794405534, Inference time: 0.001
# Inference on 4_7_5_3.csv test set trajectory
# 4_7_5_3.csv: True Class: 1, Predicted: 1, Probability: 0.9999999999999896, Inference time: 0.001
# Inference on 4_7_5_4.csv test set trajectory
# 4_7_5_4.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.002
# Inference on 4_7_5_5.csv test set trajectory
# 4_7_5_5.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.001
# Inference on 4_7_6_1.csv test set trajectory
# 4_7_6_1.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.002
# Inference on 4_7_6_2.csv test set trajectory
# 4_7_6_2.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.001
# Inference on 4_7_6_3.csv test set trajectory
# 4_7_6_3.csv: True Class: 1, Predicted: 1, Probability: 0.999999999917182, Inference time: 0.002
# Inference on 4_7_6_4.csv test set trajectory
# 4_7_6_4.csv: True Class: 1, Predicted: 1, Probability: 1.0, Inference time: 0.001
# Inference on 4_7_6_5.csv test set trajectory
# 4_7_6_5.csv: True Class: 1, Predicted: 1, Probability: 0.9999999281439242, Inference time: 0.002
# 	. result printing
#
# M0_CTNB results printing
# Execute tests (END)
#
# Comparison tests:
#
# Comparison tests (END)

# %% [markdown]
# # Test how to extract the results from test

# %%
df_metrics = pd.read_csv(os.path.join(outDir, 'metrics.csv'), sep = ';')
df_metrics.head(4)
# Out:
#                Test    Model  Aggregation ConfidenceLevel  DatasetDim  KFolds  \
# 0               NaN      NaN          NaN             NaN         NaN     NaN
# 1  210407_2014_Test  M0_CTNB          NaN             90%       840.0     1.0
#
#           Unnamed: 6  Accuracy          Unnamed: 8    Error  ...   FP-Rate  \
# 0        lower bound       NaN         upper bound      NaN  ...  0.000000
# 1  0.670451516476602   0.72381  0.7714729659164097  0.27619  ...  0.228571
#
#    Unnamed: 25   ROC AUC  Unnamed: 27     Brier  Avg learning time  \
# 0      1.00000  0.000000     1.000000       NaN                NaN
# 1      0.32381  0.763991     0.767891  0.268007               0.63
#
#    Var learning time  Avg inference time   Var inference time  Unnamed: 33
# 0                NaN                 NaN                  NaN          NaN
# 1                NaN            0.001471         7.634694e-07          NaN
#
# [2 rows x 34 columns]

# %%
#df_methods = pd.read_csv(os.path.join(outDir, 'methodsComparison.csv'), sep = ';')
#df_methods.head(4)

# %%
def read_results(res_dir):
    cols = ['id', 'label', 'pred', 'pred_prob']
    valid_cols = [i for i in range(0, 7, 2)] # [0, 2, 4, 6]

    results_file = glob.glob(os.path.join(res_dir, '*-results.txt'))[0]

    df_res = pd.read_csv(results_file, names=cols, skipinitialspace=True, usecols=valid_cols, sep=':|,', engine='python')
    
    return df_res

df = read_results(outDir)
df.head(5)
# Out:
#             id  label  pred  pred_prob
# 0  4_1_1_1.csv      0     0        1.0
# 1  4_1_1_2.csv      0     0        1.0
# 2  4_1_1_3.csv      0     0        1.0
# 3  4_1_1_4.csv      0     0        1.0
# 4  4_1_1_5.csv      0     0        1.0

# %%
for row in df.itertuples():
    print(row)
    #tmp_file = os.path.join(tmpDir, file)
    #df_tmp = pd.read_csv(tmp_file)
    #df_tmp.head(3)
    #df_tmp.to_csv(tmp_file, header=True, index=False)
# Out:
# Pandas(Index=0, id='4_1_1_1.csv', label=0, pred=0, pred_prob=1.0)
# Pandas(Index=1, id='4_1_1_2.csv', label=0, pred=0, pred_prob=1.0)
# Pandas(Index=2, id='4_1_1_3.csv', label=0, pred=0, pred_prob=1.0)
# Pandas(Index=3, id='4_1_1_4.csv', label=0, pred=0, pred_prob=1.0)
# Pandas(Index=4, id='4_1_1_5.csv', label=0, pred=0, pred_prob=1.0)
# Pandas(Index=5, id='4_1_2_1.csv', label=0, pred=0, pred_prob=1.0)
# Pandas(Index=6, id='4_1_2_2.csv', label=0, pred=0, pred_prob=1.0)
# Pandas(Index=7, id='4_1_2_3.csv', label=0, pred=0, pred_prob=1.0)
# Pandas(Index=8, id='4_1_2_4.csv', label=0, pred=0, pred_prob=1.0)
# Pandas(Index=9, id='4_1_2_5.csv', label=0, pred=0, pred_prob=1.0)
# Pandas(Index=10, id='4_1_3_1.csv', label=0, pred=0, pred_prob=1.0)
# Pandas(Index=11, id='4_1_3_2.csv', label=0, pred=0, pred_prob=1.0)
# Pandas(Index=12, id='4_1_3_3.csv', label=0, pred=0, pred_prob=1.0)
# Pandas(Index=13, id='4_1_3_4.csv', label=0, pred=0, pred_prob=1.0)
# Pandas(Index=14, id='4_1_3_5.csv', label=0, pred=0, pred_prob=1.0)
# Pandas(Index=15, id='4_1_4_1.csv', label=1, pred=0, pred_prob=1.0)
# Pandas(Index=16, id='4_1_4_2.csv', label=1, pred=0, pred_prob=1.0)
# Pandas(Index=17, id='4_1_4_3.csv', label=1, pred=0, pred_prob=1.0)
# Pandas(Index=18, id='4_1_4_4.csv', label=1, pred=0, pred_prob=1.0)
# Pandas(Index=19, id='4_1_4_5.csv', label=1, pred=0, pred_prob=1.0)
# Pandas(Index=20, id='4_1_5_1.csv', label=1, pred=1, pred_prob=1.0)
# Pandas(Index=21, id='4_1_5_2.csv', label=1, pred=1, pred_prob=1.0)
# Pandas(Index=22, id='4_1_5_3.csv', label=1, pred=1, pred_prob=1.0)
# Pandas(Index=23, id='4_1_5_4.csv', label=1, pred=1, pred_prob=1.0)
# Pandas(Index=24, id='4_1_5_5.csv', label=1, pred=1, pred_prob=1.0)
# Pandas(Index=25, id='4_1_6_1.csv', label=1, pred=1, pred_prob=1.0)
# Pandas(Index=26, id='4_1_6_2.csv', label=1, pred=1, pred_prob=1.0)
# Pandas(Index=27, id='4_1_6_3.csv', label=1, pred=1, pred_prob=1.0)
# Pandas(Index=28, id='4_1_6_4.csv', label=1, pred=1, pred_prob=1.0)
# Pandas(Index=29, id='4_1_6_5.csv', label=1, pred=1, pred_prob=1.0)
# Pandas(Index=30, id='4_2_1_1.csv', label=0, pred=1, pred_prob=1.0)
# Pandas(Index=31, id='4_2_1_2.csv', label=0, pred=0, pred_prob=1.0)
# Pandas(Index=32, id='4_2_1_3.csv', label=0, pred=0, pred_prob=1.0)
# Pandas(Index=33, id='4_2_1_4.csv', label=0, pred=0, pred_prob=1.0)
# Pandas(Index=34, id='4_2_1_5.csv', label=0, pred=1, pred_prob=0.9999999989641384)
# Pandas(Index=35, id='4_2_2_1.csv', label=0, pred=0, pred_prob=1.0)
# Pandas(Index=36, id='4_2_2_2.csv', label=0, pred=0, pred_prob=1.0)
# Pandas(Index=37, id='4_2_2_3.csv', label=0, pred=0, pred_prob=1.0)
# Pandas(Index=38, id='4_2_2_4.csv', label=0, pred=0, pred_prob=1.0)
# Pandas(Index=39, id='4_2_2_5.csv', label=0, pred=1, pred_prob=0.99996992896867)
# Pandas(Index=40, id='4_2_3_1.csv', label=0, pred=1, pred_prob=0.9999999999929808)
# Pandas(Index=41, id='4_2_3_2.csv', label=0, pred=0, pred_prob=1.0)
# Pandas(Index=42, id='4_2_3_3.csv', label=0, pred=0, pred_prob=1.0)
# Pandas(Index=43, id='4_2_3_4.csv', label=0, pred=0, pred_prob=1.0)
# Pandas(Index=44, id='4_2_3_5.csv', label=0, pred=0, pred_prob=1.0)
# Pandas(Index=45, id='4_2_4_1.csv', label=1, pred=1, pred_prob=0.9999999933429627)
# Pandas(Index=46, id='4_2_4_2.csv', label=1, pred=0, pred_prob=0.9999897502992572)
# Pandas(Index=47, id='4_2_4_3.csv', label=1, pred=1, pred_prob=1.0)
# Pandas(Index=48, id='4_2_4_4.csv', label=1, pred=1, pred_prob=0.9999999999989712)
# Pandas(Index=49, id='4_2_4_5.csv', label=1, pred=1, pred_prob=0.9999999999999234)
# Pandas(Index=50, id='4_2_5_1.csv', label=1, pred=1, pred_prob=1.0)
# Pandas(Index=51, id='4_2_5_2.csv', label=1, pred=1, pred_prob=1.0)
# Pandas(Index=52, id='4_2_5_3.csv', label=1, pred=1, pred_prob=0.9999999999854235)
# Pandas(Index=53, id='4_2_5_4.csv', label=1, pred=1, pred_prob=0.999999999999924)
# Pandas(Index=54, id='4_2_5_5.csv', label=1, pred=1, pred_prob=1.0)
# Pandas(Index=55, id='4_2_6_1.csv', label=1, pred=1, pred_prob=1.0)
# Pandas(Index=56, id='4_2_6_2.csv', label=1, pred=1, pred_prob=1.0)
# Pandas(Index=57, id='4_2_6_3.csv', label=1, pred=1, pred_prob=1.0)
# Pandas(Index=58, id='4_2_6_4.csv', label=1, pred=1, pred_prob=1.0)
# Pandas(Index=59, id='4_2_6_5.csv', label=1, pred=1, pred_prob=1.0)
# Pandas(Index=60, id='4_3_1_1.csv', label=0, pred=1, pred_prob=1.0)
# Pandas(Index=61, id='4_3_1_2.csv', label=0, pred=1, pred_prob=0.9999999999996156)
# Pandas(Index=62, id='4_3_1_3.csv', label=0, pred=0, pred_prob=0.5809568588189802)
# Pandas(Index=63, id='4_3_1_4.csv', label=0, pred=1, pred_prob=0.9999987178223404)
# Pandas(Index=64, id='4_3_1_5.csv', label=0, pred=1, pred_prob=1.0)
# Pandas(Index=65, id='4_3_2_1.csv', label=0, pred=1, pred_prob=0.9999999999999998)
# Pandas(Index=66, id='4_3_2_2.csv', label=0, pred=1, pred_prob=1.0)
# Pandas(Index=67, id='4_3_2_3.csv', label=0, pred=1, pred_prob=0.9999999999879264)
# Pandas(Index=68, id='4_3_2_4.csv', label=0, pred=1, pred_prob=0.9999999999999998)
# Pandas(Index=69, id='4_3_2_5.csv', label=0, pred=1, pred_prob=0.999999999227874)
# Pandas(Index=70, id='4_3_3_1.csv', label=0, pred=1, pred_prob=0.9999557160767746)
# Pandas(Index=71, id='4_3_3_2.csv', label=0, pred=1, pred_prob=0.9999990536993156)
# Pandas(Index=72, id='4_3_3_3.csv', label=0, pred=1, pred_prob=0.9999676836755184)
# Pandas(Index=73, id='4_3_3_4.csv', label=0, pred=1, pred_prob=0.9999999964057434)
# Pandas(Index=74, id='4_3_3_5.csv', label=0, pred=1, pred_prob=0.9999999996718602)
# Pandas(Index=75, id='4_3_4_1.csv', label=1, pred=1, pred_prob=1.0)
# Pandas(Index=76, id='4_3_4_2.csv', label=1, pred=1, pred_prob=0.999999999999876)
# Pandas(Index=77, id='4_3_4_3.csv', label=1, pred=1, pred_prob=0.9999999999999992)
# Pandas(Index=78, id='4_3_4_4.csv', label=1, pred=1, pred_prob=0.9997868842884596)
# Pandas(Index=79, id='4_3_4_5.csv', label=1, pred=1, pred_prob=0.9999999999442784)
# Pandas(Index=80, id='4_3_5_1.csv', label=1, pred=1, pred_prob=1.0)
# Pandas(Index=81, id='4_3_5_2.csv', label=1, pred=1, pred_prob=1.0)
# Pandas(Index=82, id='4_3_5_3.csv', label=1, pred=1, pred_prob=1.0)
# Pandas(Index=83, id='4_3_5_4.csv', label=1, pred=1, pred_prob=1.0)
# Pandas(Index=84, id='4_3_5_5.csv', label=1, pred=1, pred_prob=1.0)
# Pandas(Index=85, id='4_3_6_1.csv', label=1, pred=1, pred_prob=0.9999998528207038)
# Pandas(Index=86, id='4_3_6_2.csv', label=1, pred=1, pred_prob=1.0)
# Pandas(Index=87, id='4_3_6_3.csv', label=1, pred=1, pred_prob=1.0)
# Pandas(Index=88, id='4_3_6_4.csv', label=1, pred=1, pred_prob=0.9999999998769612)
# Pandas(Index=89, id='4_3_6_5.csv', label=1, pred=1, pred_prob=1.0)
# Pandas(Index=90, id='4_4_1_1.csv', label=0, pred=0, pred_prob=1.0)
# Pandas(Index=91, id='4_4_1_2.csv', label=0, pred=0, pred_prob=1.0)
# Pandas(Index=92, id='4_4_1_3.csv', label=0, pred=0, pred_prob=1.0)
# Pandas(Index=93, id='4_4_1_4.csv', label=0, pred=0, pred_prob=1.0)
# Pandas(Index=94, id='4_4_1_5.csv', label=0, pred=0, pred_prob=1.0)
# Pandas(Index=95, id='4_4_2_1.csv', label=0, pred=0, pred_prob=1.0)
# Pandas(Index=96, id='4_4_2_2.csv', label=0, pred=0, pred_prob=1.0)
# Pandas(Index=97, id='4_4_2_3.csv', label=0, pred=0, pred_prob=1.0)
# Pandas(Index=98, id='4_4_2_4.csv', label=0, pred=0, pred_prob=1.0)
# Pandas(Index=99, id='4_4_2_5.csv', label=0, pred=0, pred_prob=1.0)
# Pandas(Index=100, id='4_4_3_1.csv', label=0, pred=0, pred_prob=1.0)
# Pandas(Index=101, id='4_4_3_2.csv', label=0, pred=0, pred_prob=1.0)
# Pandas(Index=102, id='4_4_3_3.csv', label=0, pred=0, pred_prob=1.0)
# Pandas(Index=103, id='4_4_3_4.csv', label=0, pred=0, pred_prob=1.0)
# Pandas(Index=104, id='4_4_3_5.csv', label=0, pred=0, pred_prob=1.0)
# Pandas(Index=105, id='4_4_4_1.csv', label=1, pred=1, pred_prob=0.970089489842832)
# Pandas(Index=106, id='4_4_4_2.csv', label=1, pred=1, pred_prob=0.9973496440492496)
# Pandas(Index=107, id='4_4_4_3.csv', label=1, pred=1, pred_prob=0.9986379327989612)
# Pandas(Index=108, id='4_4_4_4.csv', label=1, pred=1, pred_prob=0.999418935502398)
# Pandas(Index=109, id='4_4_4_5.csv', label=1, pred=1, pred_prob=0.9703320845953703)
# Pandas(Index=110, id='4_4_5_1.csv', label=1, pred=1, pred_prob=0.9999999999999988)
# Pandas(Index=111, id='4_4_5_2.csv', label=1, pred=1, pred_prob=0.999998653312798)
# Pandas(Index=112, id='4_4_5_3.csv', label=1, pred=1, pred_prob=0.9809293672844192)
# Pandas(Index=113, id='4_4_5_4.csv', label=1, pred=1, pred_prob=0.9979156860686688)
# Pandas(Index=114, id='4_4_5_5.csv', label=1, pred=1, pred_prob=0.9957839136637482)
# Pandas(Index=115, id='4_4_6_1.csv', label=1, pred=1, pred_prob=0.99999999938012)
# Pandas(Index=116, id='4_4_6_2.csv', label=1, pred=1, pred_prob=0.9999886755405892)
# Pandas(Index=117, id='4_4_6_3.csv', label=1, pred=1, pred_prob=1.0)
# Pandas(Index=118, id='4_4_6_4.csv', label=1, pred=1, pred_prob=0.9999999881706046)
# Pandas(Index=119, id='4_4_6_5.csv', label=1, pred=1, pred_prob=0.9593135277596742)
# Pandas(Index=120, id='4_5_1_1.csv', label=0, pred=0, pred_prob=1.0)
# Pandas(Index=121, id='4_5_1_2.csv', label=0, pred=0, pred_prob=1.0)
# Pandas(Index=122, id='4_5_1_3.csv', label=0, pred=0, pred_prob=1.0)
# Pandas(Index=123, id='4_5_1_4.csv', label=0, pred=1, pred_prob=0.9999999913633418)
# Pandas(Index=124, id='4_5_1_5.csv', label=0, pred=0, pred_prob=1.0)
# Pandas(Index=125, id='4_5_2_1.csv', label=0, pred=0, pred_prob=1.0)
# Pandas(Index=126, id='4_5_2_2.csv', label=0, pred=0, pred_prob=1.0)
# Pandas(Index=127, id='4_5_2_3.csv', label=0, pred=0, pred_prob=1.0)
# Pandas(Index=128, id='4_5_2_4.csv', label=0, pred=0, pred_prob=1.0)
# Pandas(Index=129, id='4_5_2_5.csv', label=0, pred=0, pred_prob=1.0)
# Pandas(Index=130, id='4_5_3_1.csv', label=0, pred=0, pred_prob=1.0)
# Pandas(Index=131, id='4_5_3_2.csv', label=0, pred=0, pred_prob=1.0)
# Pandas(Index=132, id='4_5_3_3.csv', label=0, pred=0, pred_prob=1.0)
# Pandas(Index=133, id='4_5_3_4.csv', label=0, pred=0, pred_prob=1.0)
# Pandas(Index=134, id='4_5_3_5.csv', label=0, pred=0, pred_prob=1.0)
# Pandas(Index=135, id='4_5_4_1.csv', label=1, pred=0, pred_prob=1.0)
# Pandas(Index=136, id='4_5_4_2.csv', label=1, pred=0, pred_prob=1.0)
# Pandas(Index=137, id='4_5_4_3.csv', label=1, pred=0, pred_prob=1.0)
# Pandas(Index=138, id='4_5_4_4.csv', label=1, pred=0, pred_prob=1.0)
# Pandas(Index=139, id='4_5_4_5.csv', label=1, pred=0, pred_prob=1.0)
# Pandas(Index=140, id='4_5_5_1.csv', label=1, pred=0, pred_prob=1.0)
# Pandas(Index=141, id='4_5_5_2.csv', label=1, pred=0, pred_prob=1.0)
# Pandas(Index=142, id='4_5_5_3.csv', label=1, pred=0, pred_prob=1.0)
# Pandas(Index=143, id='4_5_5_4.csv', label=1, pred=1, pred_prob=1.0)
# Pandas(Index=144, id='4_5_5_5.csv', label=1, pred=0, pred_prob=0.0)
# Pandas(Index=145, id='4_5_6_1.csv', label=1, pred=1, pred_prob=0.0)
# Pandas(Index=146, id='4_5_6_2.csv', label=1, pred=1, pred_prob=1.0)
# Pandas(Index=147, id='4_5_6_3.csv', label=1, pred=1, pred_prob=1.0)
# Pandas(Index=148, id='4_5_6_4.csv', label=1, pred=1, pred_prob=1.0)
# Pandas(Index=149, id='4_5_6_5.csv', label=1, pred=1, pred_prob=1.0)
# Pandas(Index=150, id='4_6_1_1.csv', label=0, pred=1, pred_prob=1.0)
# Pandas(Index=151, id='4_6_1_2.csv', label=0, pred=1, pred_prob=1.0)
# Pandas(Index=152, id='4_6_1_3.csv', label=0, pred=1, pred_prob=1.0)
# Pandas(Index=153, id='4_6_1_4.csv', label=0, pred=1, pred_prob=1.0)
# Pandas(Index=154, id='4_6_1_5.csv', label=0, pred=1, pred_prob=1.0)
# Pandas(Index=155, id='4_6_2_1.csv', label=0, pred=1, pred_prob=0.0)
# Pandas(Index=156, id='4_6_2_2.csv', label=0, pred=1, pred_prob=0.0)
# Pandas(Index=157, id='4_6_2_3.csv', label=0, pred=0, pred_prob=1.0)
# Pandas(Index=158, id='4_6_2_4.csv', label=0, pred=0, pred_prob=1.0)
# Pandas(Index=159, id='4_6_2_5.csv', label=0, pred=0, pred_prob=1.0)
# Pandas(Index=160, id='4_6_3_1.csv', label=0, pred=1, pred_prob=0.999999999998964)
# Pandas(Index=161, id='4_6_3_2.csv', label=0, pred=1, pred_prob=1.0)
# Pandas(Index=162, id='4_6_3_3.csv', label=0, pred=1, pred_prob=0.999999999999874)
# Pandas(Index=163, id='4_6_3_4.csv', label=0, pred=1, pred_prob=1.0)
# Pandas(Index=164, id='4_6_3_5.csv', label=0, pred=1, pred_prob=0.9999980113991987)
# Pandas(Index=165, id='4_6_4_1.csv', label=1, pred=1, pred_prob=0.9999317263149154)
# Pandas(Index=166, id='4_6_4_2.csv', label=1, pred=1, pred_prob=1.0)
# Pandas(Index=167, id='4_6_4_3.csv', label=1, pred=1, pred_prob=1.0)
# Pandas(Index=168, id='4_6_4_4.csv', label=1, pred=1, pred_prob=1.0)
# Pandas(Index=169, id='4_6_4_5.csv', label=1, pred=1, pred_prob=1.0)
# Pandas(Index=170, id='4_6_5_1.csv', label=1, pred=1, pred_prob=0.9993621450684834)
# Pandas(Index=171, id='4_6_5_2.csv', label=1, pred=1, pred_prob=0.7642833472470801)
# Pandas(Index=172, id='4_6_5_3.csv', label=1, pred=1, pred_prob=0.9999995750586348)
# Pandas(Index=173, id='4_6_5_4.csv', label=1, pred=1, pred_prob=1.0)
# Pandas(Index=174, id='4_6_5_5.csv', label=1, pred=1, pred_prob=1.0)
# Pandas(Index=175, id='4_6_6_1.csv', label=1, pred=0, pred_prob=1.0)
# Pandas(Index=176, id='4_6_6_2.csv', label=1, pred=0, pred_prob=1.0)
# Pandas(Index=177, id='4_6_6_3.csv', label=1, pred=0, pred_prob=1.0)
# Pandas(Index=178, id='4_6_6_4.csv', label=1, pred=0, pred_prob=1.0)
# Pandas(Index=179, id='4_6_6_5.csv', label=1, pred=0, pred_prob=1.0)
# Pandas(Index=180, id='4_7_1_1.csv', label=0, pred=0, pred_prob=1.0)
# Pandas(Index=181, id='4_7_1_2.csv', label=0, pred=0, pred_prob=1.0)
# Pandas(Index=182, id='4_7_1_3.csv', label=0, pred=0, pred_prob=1.0)
# Pandas(Index=183, id='4_7_1_4.csv', label=0, pred=0, pred_prob=1.0)
# Pandas(Index=184, id='4_7_1_5.csv', label=0, pred=0, pred_prob=1.0)
# Pandas(Index=185, id='4_7_2_1.csv', label=0, pred=0, pred_prob=1.0)
# Pandas(Index=186, id='4_7_2_2.csv', label=0, pred=0, pred_prob=1.0)
# Pandas(Index=187, id='4_7_2_3.csv', label=0, pred=0, pred_prob=1.0)
# Pandas(Index=188, id='4_7_2_4.csv', label=0, pred=0, pred_prob=1.0)
# Pandas(Index=189, id='4_7_2_5.csv', label=0, pred=0, pred_prob=1.0)
# Pandas(Index=190, id='4_7_3_1.csv', label=0, pred=0, pred_prob=1.0)
# Pandas(Index=191, id='4_7_3_2.csv', label=0, pred=0, pred_prob=1.0)
# Pandas(Index=192, id='4_7_3_3.csv', label=0, pred=1, pred_prob=0.9999999741574374)
# Pandas(Index=193, id='4_7_3_4.csv', label=0, pred=1, pred_prob=1.0)
# Pandas(Index=194, id='4_7_3_5.csv', label=0, pred=1, pred_prob=0.9999993926226944)
# Pandas(Index=195, id='4_7_4_1.csv', label=1, pred=0, pred_prob=0.999999999999118)
# Pandas(Index=196, id='4_7_4_2.csv', label=1, pred=1, pred_prob=0.7803092012331205)
# Pandas(Index=197, id='4_7_4_3.csv', label=1, pred=0, pred_prob=0.9994248844282264)
# Pandas(Index=198, id='4_7_4_4.csv', label=1, pred=0, pred_prob=0.9998357316997576)
# Pandas(Index=199, id='4_7_4_5.csv', label=1, pred=0, pred_prob=1.0)
# Pandas(Index=200, id='4_7_5_1.csv', label=1, pred=1, pred_prob=0.999997925050605)
# Pandas(Index=201, id='4_7_5_2.csv', label=1, pred=1, pred_prob=0.9999999794405534)
# Pandas(Index=202, id='4_7_5_3.csv', label=1, pred=1, pred_prob=0.9999999999999896)
# Pandas(Index=203, id='4_7_5_4.csv', label=1, pred=1, pred_prob=1.0)
# Pandas(Index=204, id='4_7_5_5.csv', label=1, pred=1, pred_prob=1.0)
# Pandas(Index=205, id='4_7_6_1.csv', label=1, pred=1, pred_prob=1.0)
# Pandas(Index=206, id='4_7_6_2.csv', label=1, pred=1, pred_prob=1.0)
# Pandas(Index=207, id='4_7_6_3.csv', label=1, pred=1, pred_prob=0.999999999917182)
# Pandas(Index=208, id='4_7_6_4.csv', label=1, pred=1, pred_prob=1.0)
# Pandas(Index=209, id='4_7_6_5.csv', label=1, pred=1, pred_prob=0.9999999281439242)

# %%
df_tmp.head(10)
# Out:
#                    S1                    S2                     S3  \
# 0  (-8913.0, -8347.0]  (-15256.0, -14063.5]  (-19579.15, -18702.2]
# 1  (-8913.0, -8347.0]  (-15256.0, -14063.5]  (-19579.15, -18702.2]
# 2  (-8913.0, -8347.0]  (-15256.0, -14063.5]  (-19579.15, -18702.2]
# 3  (-8913.0, -8347.0]  (-15256.0, -14063.5]  (-19579.15, -18702.2]
# 4  (-8913.0, -8347.0]  (-15256.0, -14063.5]  (-19579.15, -18702.2]
# 5  (-8913.0, -8347.0]  (-15256.0, -14063.5]  (-19579.15, -18702.2]
# 6  (-8913.0, -8347.0]  (-15256.0, -14063.5]  (-19579.15, -18702.2]
# 7  (-8913.0, -8347.0]  (-15256.0, -14063.5]  (-19579.15, -18702.2]
# 8  (-8913.0, -8347.0]  (-15256.0, -14063.5]  (-19579.15, -18702.2]
# 9  (-8913.0, -8347.0]  (-15256.0, -14063.5]  (-19579.15, -18702.2]
#
#                      S4                     S5                    S6  \
# 0  (-15064.2, -13936.6]  (-13423.35, -11919.8]  (-26890.5, -26622.4]
# 1  (-15064.2, -13936.6]  (-13423.35, -11919.8]  (-26890.5, -26622.4]
# 2  (-15064.2, -13936.6]  (-13423.35, -11919.8]  (-26890.5, -26622.4]
# 3  (-15064.2, -13936.6]  (-13423.35, -11919.8]  (-26890.5, -26622.4]
# 4  (-15064.2, -13936.6]  (-13423.35, -11919.8]  (-26890.5, -26622.4]
# 5  (-15064.2, -13936.6]  (-13423.35, -11919.8]  (-26890.5, -26622.4]
# 6  (-15064.2, -13936.6]  (-13423.35, -11919.8]  (-26890.5, -26622.4]
# 7  (-15064.2, -13936.6]  (-13423.35, -11919.8]  (-26890.5, -26622.4]
# 8  (-15064.2, -13936.6]  (-13423.35, -11919.8]  (-26890.5, -26622.4]
# 9  (-15064.2, -13936.6]  (-13423.35, -11919.8]  (-26890.5, -26622.4]
#
#                    S7                  S8                 S9  \
# 0  (-7021.4, -5340.6]  (20033.4, 21625.1]  (7179.1, 10022.2]
# 1  (-7021.4, -5340.6]  (20033.4, 21625.1]  (7179.1, 10022.2]
# 2  (-7021.4, -5340.6]  (20033.4, 21625.1]  (7179.1, 10022.2]
# 3  (-7021.4, -5340.6]  (20033.4, 21625.1]  (7179.1, 10022.2]
# 4  (-7021.4, -5340.6]  (20033.4, 21625.1]  (7179.1, 10022.2]
# 5  (-7021.4, -5340.6]  (20033.4, 21625.1]  (7179.1, 10022.2]
# 6  (-7021.4, -5340.6]  (20033.4, 21625.1]  (7179.1, 10022.2]
# 7  (-7021.4, -5340.6]  (20033.4, 21625.1]  (7179.1, 10022.2]
# 8  (-7021.4, -5340.6]  (20033.4, 21625.1]  (7179.1, 10022.2]
# 9  (-7021.4, -5340.6]  (20033.4, 21625.1]  (7179.1, 10022.2]
#
#                    S10  ...                   S24                 S25  \
# 0  (-3846.5, -1798.55]  ...  (-20469.3, -19157.6]  (-6371.4, -4607.6]
# 1  (-3846.5, -1798.55]  ...  (-20469.3, -19157.6]  (-6371.4, -4607.6]
# 2  (-3846.5, -1798.55]  ...  (-20469.3, -19157.6]  (-6371.4, -4607.6]
# 3  (-3846.5, -1798.55]  ...  (-20469.3, -19157.6]  (-6371.4, -4607.6]
# 4  (-3846.5, -1798.55]  ...  (-20469.3, -19157.6]  (-6371.4, -4607.6]
# 5  (-3846.5, -1798.55]  ...  (-20469.3, -19157.6]  (-6371.4, -4607.6]
# 6  (-3846.5, -1798.55]  ...  (-20469.3, -19157.6]  (-6371.4, -4607.6]
# 7  (-3846.5, -1798.55]  ...  (-20469.3, -19157.6]  (-6371.4, -4607.6]
# 8  (-3846.5, -1798.55]  ...  (-20469.3, -19157.6]  (-6371.4, -4607.6]
# 9  (-3846.5, -1798.55]  ...  (-20469.3, -19157.6]  (-6371.4, -4607.6]
#
#                      S26                    S27                   S28  \
# 0  (-23083.25, -21921.9]  (-16061.95, -15220.8]  (-20713.0, -19627.0]
# 1  (-23083.25, -21921.9]  (-16903.1, -16061.95]  (-20713.0, -19627.0]
# 2  (-23083.25, -21921.9]  (-16061.95, -15220.8]  (-20713.0, -19627.0]
# 3  (-23083.25, -21921.9]  (-16903.1, -16061.95]  (-20713.0, -19627.0]
# 4  (-23083.25, -21921.9]  (-16903.1, -16061.95]  (-20713.0, -19627.0]
# 5  (-23083.25, -21921.9]  (-16903.1, -16061.95]  (-20713.0, -19627.0]
# 6  (-23083.25, -21921.9]  (-16903.1, -16061.95]  (-20713.0, -19627.0]
# 7  (-23083.25, -21921.9]  (-16903.1, -16061.95]  (-20713.0, -19627.0]
# 8  (-23083.25, -21921.9]  (-16903.1, -16061.95]  (-20713.0, -19627.0]
# 9  (-23083.25, -21921.9]  (-16903.1, -16061.95]  (-20713.0, -19627.0]
#
#                   S29     t Exercise ExerciseMode  0
# 0  (13388.6, 14639.4]  0.00        7            1  3
# 1  (13388.6, 14639.4]  0.03        7            1  3
# 2  (13388.6, 14639.4]  0.06        7            1  3
# 3  (13388.6, 14639.4]  0.09        7            1  3
# 4  (13388.6, 14639.4]  0.12        7            1  3
# 5  (13388.6, 14639.4]  0.15        7            1  3
# 6  (13388.6, 14639.4]  0.18        7            1  3
# 7  (13388.6, 14639.4]  0.21        7            1  3
# 8  (13388.6, 14639.4]  0.24        7            1  3
# 9  (13388.6, 14639.4]  0.27        7            1  3
#
# [10 rows x 33 columns]

# %%
def reset_data(orig_dir, dest_dir):
    try:
        if os.path.exists(dest_dir):
            shutil.rmtree(dest_dir)
        shutil.copytree(orig_dir, dest_dir)
    except:
        return False
    return True

reset_data(inDir, tmpDir)
# Out:
# True

# %%
accuracy_score(df['label'], df['pred'])
# Out:
# 0.7238095238095238

# %% [markdown]
# # CTBNC chain

# %%
inDir = os.path.join('data', 'rehab')
tmpDir = os.path.join('data', 'rehab-tmp')

features = ['S1','S2','S3','S4','S5','S6','S7','S8','S9','S10','S11','S12',
            'S13','S14','S15','S16','S17','S18','S19','S20','S21','S22','S23',
            'S24','S25','S26','S27','S28','S29']
time = 't'
labels = ['ExerciseMode','Exercise']
models = 'CTNB'
train_perc = 0.75


features_cmd = ','.join(f"{item}" for item in features)
features_cmd
# Out:
# 'S1,S2,S3,S4,S5,S6,S7,S8,S9,S10,S11,S12,S13,S14,S15,S16,S17,S18,S19,S20,S21,S22,S23,S24,S25,S26,S27,S28,S29'

# %%
def read_results(res_dir):
    cols = ['id', 'label', 'pred', 'pred_prob']
    valid_cols = [i for i in range(0, 7, 2)] # [0, 2, 4, 6]

    results_file = glob.glob(os.path.join(res_dir, '*-results.txt'))[0]

    df_res = pd.read_csv(results_file, names=cols, skipinitialspace=True, usecols=valid_cols, sep=':|,', engine='python')
    
    return df_res

def reset_data(orig_dir, dest_dir):
    try:
        if os.path.exists(dest_dir):
            shutil.rmtree(dest_dir)
        shutil.copytree(orig_dir, dest_dir)
    except:
        return False
    return True

# %%
for item in labels:
    outDir = os.path.join('results', item) # Generate the directory to store the results
    
    # Run the application to generate, train and test the classifier
    # !java -jar CTBNCToolkit.jar --CTBNC={models} --validation=HO,{train_perc} --validColumns={features_cmd} --timeName={time} --className={item} --rPath={outDir} {tmpDir}
    
    # Get the predictions for the test subset
    df_res = read_results(outDir)
    acc = accuracy_score(df_res['label'], df_res['pred'])
    print('Accuracy score for', item, '->', acc )
    
    # Save them for the next model of the chain to use them
    for row in df_res.itertuples():
        file = row[1]
        #label = row[2]
        pred = row[3]
        #prob = row[4]
        tmp_file = os.path.join(tmpDir, file)
        df_tmp = pd.read_csv(tmp_file)
        df_tmp[item] = pred # Set the prediction of the classifier as the input for the next classifier
        df_tmp.to_csv(tmp_file, header=True, index=False)
    
    # Finally append the label to the features for the next model to use it as input
    features.append(item)
    features_cmd = ','.join(f"{item}" for item in features)
# Out:
# M0_CTNB results printing
# Accuracy score for ExerciseMode -> 0.7238095238095238
# Error: NaN probability value
# Error: NaN probability value
# M0_CTNB results printing
# Accuracy score for Exercise -> 0.625

# %%
# Restore the tmp directory
reset_data(inDir, tmpDir)
# Out:
# True

# %% [markdown]
# # Binary relevance

# %%
inDir = os.path.join('data', 'rehab')
tmpDir = os.path.join('data', 'rehab-tmp')

features = ['S1','S2','S3','S4','S5','S6','S7','S8','S9','S10','S11','S12',
            'S13','S14','S15','S16','S17','S18','S19','S20','S21','S22','S23',
            'S24','S25','S26','S27','S28','S29']
time = 't'
labels = ['Exercise','ExerciseMode']
models = 'CTNB'
train_perc = 0.75


features_cmd = ','.join(f"{item}" for item in features)
features_cmd
# Out:
# 'S1,S2,S3,S4,S5,S6,S7,S8,S9,S10,S11,S12,S13,S14,S15,S16,S17,S18,S19,S20,S21,S22,S23,S24,S25,S26,S27,S28,S29'

# %%
for item in labels:
    outDir = os.path.join('results', item) # Generate the directory to store the results
    
    # Run the application to generate, train and test the classifier
    # !java -jar CTBNCToolkit.jar --CTBNC={models} --validation=HO,{train_perc} --validColumns={features_cmd} --timeName={time} --className={item} --rPath={outDir} {tmpDir}
    
    # Get the predictions for the test subset
    df_res = read_results(outDir)
    acc = accuracy_score(df_res['label'], df_res['pred'])
    print('Accuracy score for', item, '->', acc )
# Out:
# Error: NaN probability value
# Error: NaN probability value
# M0_CTNB results printing
# Accuracy score for Exercise -> 0.625
# M0_CTNB results printing
# Accuracy score for ExerciseMode -> 0.7238095238095238

# %%
# Restore the tmp directory
reset_data(inDir, tmpDir)
