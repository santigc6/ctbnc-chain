# %% [markdown]
# ## Dataset generation

# %%
import os
import pandas as pd
from sktime.utils.data_io import load_from_arff_to_dataframe

# %%
PATH = 'C:/Users/berna/Downloads/Multivariate2018_arff/Multivariate_arff'

# %%
train_x, train_y = load_from_arff_to_dataframe(
    os.path.join(PATH, "EigenWorms_TFM/EigenWormsDimension1_TRAIN.arff")
)
test_x, test_y = load_from_arff_to_dataframe(
    os.path.join(PATH, "EigenWorms_TFM/EigenWormsDimension1_TEST.arff")
)

# %%
pd.set_option('display.max_colwidth', None)

# %%
train_x.head()
# Out:
#                                                                                                                                                                                                                                  dim_0
# 0  0       -0.869467
# 1       -0.759418
# 2       -0.703444
# 3       -0.584800
# 4       -0.355616
#            ...
# 17979   -1.174038
# 17980   -1.143847
# 17981   -1.151561
# 17982   -1.173736
# 17983   -1.223899
# Length: 17984, dtype: float64
# 1  0       -1.943972
# 1       -1.945142
# 2       -1.954392
# 3       -2.018798
# 4       -2.014180
#            ...
# 17979    1.826259
# 17980    1.904042
# 17981    1.921922
# 17982    1.884129
# 17983    1.978157
# Length: 17984, dtype: float64
# 2  0        1.618473
# 1        1.669408
# 2        1.706154
# 3        1.680708
# 4        1.618054
#            ...
# 17979    1.489463
# 17980    1.337108
# 17981    1.250882
# 17982    1.123102
# 17983    0.951868
# Length: 17984, dtype: float64
# ...

# %%
train_y.shape
# Out:
# (128,)

# %%
train_x, train_y = load_from_arff_to_dataframe(
    os.path.join(PATH, "EigenWorms_TFM/EigenWormsDimension2_TRAIN.arff")
)
test_x, test_y = load_from_arff_to_dataframe(
    os.path.join(PATH, "EigenWorms_TFM/EigenWormsDimension2_TEST.arff")
)

# %%
train_x.head()
# Out:
#                                                                                                                                                                                                                                  dim_0
# 0  0        2.320568
# 1        2.298884
# 2        2.302923
# 3        2.204920
# 4        2.158014
#            ...
# 17979   -1.137526
# 17980   -1.126004
# 17981   -1.143096
# 17982   -1.171733
# 17983   -1.200078
# Length: 17984, dtype: float64
# 1  0        3.005051
# 1        3.029577
# 2        3.029210
# 3        3.033782
# 4        3.030836
#            ...
# 17979    2.470948
# 17980    2.445918
# 17981    2.405174
# 17982    2.440765
# 17983    2.447187
# Length: 17984, dtype: float64
# 2  0       -0.129274
# 1       -0.004588
# 2        0.273895
# 3        0.384836
# 4        0.602890
#            ...
# 17979   -0.731731
# 17980   -0.697439
# 17981   -0.729768
# 17982   -0.745052
# 17983   -0.742760
# Length: 17984, dtype: float64
# ...

# %%
train_y.shape
# Out:
# (128,)
